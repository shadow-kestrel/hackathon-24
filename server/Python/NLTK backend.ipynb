# %%
# Import the essential packages
# NLTK
# SpaCy
# Scikit-learn

# !pip install -q nltk
# !pip install -q spacy
# !pip install -q scikit-learn # Not used yet

import nltk
import spacy
import sklearn

print("Import done!")
# Out:
# ERROR: Invalid requirement: '#'
# Import done!

# %%
from nltk.probability import FreqDist
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag

nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\ew464\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# True

# %%
import utils
nltk.download("punkt", quiet = True)

print("Imported utils")
# Out:
# Imported utils

# %%
# Download Spacy English model
# !python -m spacy download en_core_web_lg > NUL 2>&1

print("Spacy English installed")
# Out:
# Spacy English installed

# %%
from nltk.corpus import twitter_samples

nltk.download("twitter_samples")
# Out:
# [nltk_data] Downloading package twitter_samples to
# [nltk_data]     C:\Users\ew464\AppData\Roaming\nltk_data...
# [nltk_data]   Package twitter_samples is already up-to-date!
# True

# %%
import re

# %%
def GetProperNouns(doc):
    properNouns = []
    for token in doc:
        if token.pos_ == "PROPN":
            properNouns.append(token.text)
    return properNouns

# %%
# Returns a list of named entities 
def GetNamedEntities(doc):
    entities = []
    for ent in doc.ents:
        entities.append(ent.text)
    return entities

# %%
def RemoveNamedEntities(doc, namedEntities):
    document = doc
    for namedEntity in namedEntities:
        if namedEntity in doc:
            document = document.replace(namedEntity, "")
    return document

# %%
# The document as a string
docstring = "Epic Games Fornite skibidi toilet anita max wynn awefawefawfwf. The game's diverse world captivates players worldwide."

# Load Spacy large English model and set up Spacy
nlp = spacy.load("en_core_web_lg")
doc = nlp(docstring)

# Get proper nouns and named entities as lists
properNouns = GetProperNouns(doc)
namedEntities = GetNamedEntities(doc)
print(properNouns)
print(namedEntities)

# Remove named entities from the document
doc_noEntities = RemoveNamedEntities(docstring, namedEntities)

# Normalize the document
doc_canonized = utils.canonize(doc_noEntities)

doc_canonized
# Out:
# ['Epic', 'Games', 'Fornite', 'skibidi', 'anita', 'max', 'wynn', 'awefawefawfwf']
# ['Epic Games', 'Fornite', 'wynn awefawefawfwf']
# ['skibidi',
#  'toilet',
#  'anita',
#  'max',
#  'The',
#  'game',
#  "'s",
#  'diverse',
#  'world',
#  'captivates',
#  'players',
#  'worldwide']

# %%
FreqDist(doc_canonized)
# Out:
# FreqDist({'skibidi': 1, 'toilet': 1, 'anita': 1, 'max': 1, 'The': 1, 'game': 1, "'s": 1, 'diverse': 1, 'world': 1, 'captivates': 1, ...})

# %%
positive_tweets = twitter_samples.strings('positive_tweets.json')
negative_tweets = twitter_samples.strings('negative_tweets.json')
tweets = positive_tweets + negative_tweets

# %%
def remove_twitter_handles(tweet):
    mention_pattern = r'@[A-Za-z0-9_]+'

    # Replace all matches with an empty string
    cleaned_text = re.sub(mention_pattern, '', tweet)
    
    return cleaned_text

# %%
def remove_twitter_hashtags(tweet):
    hashtag_pattern = r'#[A-Za-z0-9_]+'

    cleaned_text = re.sub(hashtag_pattern, '', tweet)
    
    return cleaned_text

# %%
def remove_links(text):
    doc = nlp(text)
    cleaned_text = ' '.join(token.text for token in doc if not token.like_url)
    return cleaned_text

# %%
def normalize_tweets(tweets):
    normalized_tweets = []

    for tweet in tweets:
        tweet = remove_twitter_handles(tweet)
        tweet = remove_twitter_hashtags(tweet)
        tweet = remove_links(tweet)
        tweet = utils.canonize(tweet)
        normalized_tweets.append(tweet)
    return normalized_tweets

normalized_tweets = normalize_tweets(tweets)

# %%
# Returns the token count of the whole corpora as a single FreqDist
# Input: A list of lists
# Output: A single FreqDist

def get_corpus_FreqDist(corpus):
    corpus_FreqDist = FreqDist()
    for document in corpus:
        corpus_FreqDist += FreqDist(document)
    
    return corpus_FreqDist

get_corpus_FreqDist(normalized_tweets)
# Out:
# FreqDist({'I': 3209, 'NUM': 942, "'s": 873, "n't": 839, 'D': 674, "'m": 523, '``': 478, '...': 462, 'like': 403, 'u': 391, ...})

# %%
normalized_tweets
# Out:
# [['top', 'engaged', 'members', 'community', 'week'],
#  ['Hey',
#   'James',
#   'How',
#   'odd',
#   'Please',
#   'call',
#   'Contact',
#   'Centre',
#   'NUM',
#   'able',
#   'assist',
#   'Many',
#   'thanks'],
#  ['listen',
#   'last',
#   'night',
#   'As',
#   'You',
#   'Bleed',
#   'amazing',
#   'track',
#   'When',
#   'Scotland'],
#  ['CONGRATS'],
#  ['yeaaaah',
#   'yippppy',
#   'accnt',
#   'verified',
#   'rqst',
#   'succeed',
#   'got',
#   'blue',
#   'tick',
#   'mark',
#   'fb',
#   'profile',
#   'NUM',
#   'days'],
#  ['This', 'one', 'irresistible'],
#  ['We',
#   "n't",
#   'like',
#   'keep',
#   'lovely',
#   'customers',
#   'waiting',
#   'long',
#   'We',
#   'hope',
#   'enjoy',
#   'Happy',
#   'Friday',
#   'LWWF'],
#  ['On',
#   'second',
#   'thought',
#   '’',
#   'enough',
#   'time',
#   'DD',
#   'But',
#   'new',
#   'shorts',
#   'entering',
#   'system',
#   'Sheep',
#   'must',
#   'buying'],
#  ['Jgh', 'go', 'Bayan', 'D', 'bye'],
#  ['As',
#   'act',
#   'mischievousness',
#   'calling',
#   'ETL',
#   'layer',
#   'house',
#   'warehousing',
#   'app',
#   'Katamari',
#   'Well',
#   '…',
#   'name',
#   'implies',
#   'p'],
#  ['top', 'influencers', 'community', 'week'],
#  ['Who',
#   'Would',
#   "n't",
#   'Love',
#   'These',
#   'Big',
#   '....',
#   'Juicy',
#   '....',
#   'Selfies'],
#  ['follow', 'amp', 'follow', 'u', 'back'],
#  ['Perfect', 'already', 'know', "'s", 'waiting'],
#  ['Great',
#   'new',
#   'opportunity',
#   'junior',
#   'triathletes',
#   'aged',
#   'NUM',
#   'NUM',
#   'Gatorade',
#   'series',
#   'Get',
#   'entries'],
#  ['Laying', 'greetings', 'card', 'range', 'print', 'today', 'love', 'job'],
#  ['Friend', "'s", 'lunch', '...', 'yummmm'],
#  ['conflict', 'thanks', 'help', 'D', "'s", 'screenshot', 'working'],
#  ['Hi', 'liv'],
#  ['Hello',
#   'I',
#   'need',
#   'know',
#   'something',
#   'u',
#   'fm',
#   'Twitter',
#   '—',
#   'sure',
#   'thing',
#   'dm',
#   'x'],
#  ['top', 'new', 'followers', 'community', 'week'],
#  ['I',
#   "'ve",
#   'heard',
#   'Four',
#   'Seasons',
#   'pretty',
#   'dope',
#   'Penthouse',
#   'obvs',
#   'Have',
#   'fun'],
#  ['Yeah', 'I', 'suppose', 'lol', 'Chat', 'bit', 'x'],
#  ['Hello', 'Get', 'Youth', 'Job', 'Opportunities', 'follow', 'gt', 'gt'],
#  ['💅', '🏽', '💋', "n't", 'seen', 'years'],
#  ['Thank'],
#  ['hope',
#   'rest',
#   'night',
#   'goes',
#   'quickly',
#   '...',
#   'I',
#   'bed',
#   '...',
#   'got',
#   'music',
#   'fix',
#   'time',
#   'dream'],
#  ['Spiritual',
#   'Ritual',
#   'Festival',
#   'Népal',
#   'Beginning',
#   'Line',
#   'It',
#   'left',
#   'line',
#   'See',
#   '...'],
#  ['Hey', 'Sarah', 'Send', 'us', 'email', "'ll", 'help', 'asap'],
#  ['lols', 'D'],
#  ['MY', 'kik', 'hatessuce32429'],
#  ['come', 'house'],
#  ['Effective',
#   'press',
#   'release',
#   'distribution',
#   'results',
#   'link',
#   'removed'],
#  ['Hi',
#   'BAM',
#   'Can',
#   'follow',
#   'bestfriend',
#   'She',
#   'loves',
#   'lot',
#   'See',
#   'Warsaw',
#   'lt',
#   'NUM',
#   'Love',
#   'lt',
#   'NUM',
#   'x46'],
#  ['everyone', 'watch', 'documentary', 'Earthlings', 'YouTube'],
#  ['follow', 'amp', 'follow', 'u', 'back'],
#  ['top', 'supports', 'community', 'week'],
#  ['buuuuuuuut', 'oh', 'well'],
#  ['I', 'looking', 'forward', 'visiting', 'next', 'week', 'Jo'],
#  ['makes',
#   'u',
#   'feel',
#   'better',
#   'never',
#   'see',
#   'anyone',
#   'kpop',
#   'flesh',
#   'D'],
#  ['Good', 'girl', 'Best', 'wishes'],
#  ['A',
#   'great',
#   'enough',
#   'reason',
#   'listen',
#   'one',
#   'epic',
#   'soundtrack',
#   'D'],
#  ['Thank', 'shout', 'Have', 'great', 'Friday'],
#  ['I',
#   'added',
#   'video',
#   'playlist',
#   'back',
#   'twitch',
#   'today',
#   'going',
#   'league',
#   'NUM',
#   'NUM'],
#  ['Would', 'love', 'see', 'dear', 'waiting'],
#  ['oh', 'okay', 'D', 'thanks'],
#  ['like',
#   'fake',
#   'gameplays',
#   'haha',
#   'I',
#   'kidding',
#   'kidding',
#   'You',
#   'good',
#   'stuff'],
#  ['yeah', 'exactly'],
#  ['Our', 'new', 'product', 'line', 'shop', 'Check'],
#  ['I', 'hope', 'vacation', 'going', 'great', 'D'],
#  ['rechargeable', 'normally', 'comes', 'charger', 'u', 'buy'],
#  ['top', 'engaged', 'members', 'community', 'week'],
#  ['Well', "'s", 'asleep', 'I', 'one', 'talk', 'sooo', 'someone', 'text'],
#  ['Yes',
#   'I',
#   'suppose',
#   'I',
#   'bet',
#   "'ll",
#   'blue',
#   'fit',
#   'hearing',
#   'speech',
#   'today',
#   'Pity'],
#  ['Green',
#   'gardens',
#   'midnight',
#   'sun',
#   'beautiful',
#   'canals',
#   'dasvidaniya',
#   'till',
#   'next',
#   'visit'],
#  ['scouting', 'SG', 'future', 'WLAN', 'pros', 'conference', 'Asia'],
#  ['Good', 'u', 'better', 'change', 'lollipop', '🍭'],
#  ['We', 'lt', 'NUM', 'u', 'Nez'],
#  ['Follow', 'Please', 'This', 'Big', 'Dream'],
#  ['oley', 'D'],
#  ['``', 'Mama', 'reason', 'I', 'stand', 'stronger', '``'],
#  ['follow', 'amp', 'follow', 'u', 'back'],
#  ['OH', 'MY', 'GOD', 'MISTY', 'MY', 'BABY', 'IS', 'SO', 'CUTE', 'D'],
#  ['I', 'love', 'blue'],
#  ['Woohoo',
#   'Ca',
#   "n't",
#   'wait',
#   'Have',
#   'signed',
#   'yet',
#   'still',
#   'thinking',
#   'MKa'],
#  ['liam', 'access'],
#  ['welcome'],
#  ['Stats',
#   'day',
#   'arrived',
#   'NUM',
#   'new',
#   'follower',
#   'NO',
#   'unfollowers',
#   'via'],
#  ["n't", 'surprised', '...', 'amazing', 'figure'],
#  ['top', 'influencers', 'community', 'week'],
#  ['Wishing', 'best', 'beautiful', 'sweet', 'talented', 'amazing', '…'],
#  ['NUM', 'plans', 'day', 'drain', 'great'],
#  ['got', 'ta', 'love', 'timezones', 'p'],
#  ['parents',
#   'proud',
#   '—',
#   'lol',
#   'least',
#   'D',
#   'maybe',
#   'sometimes',
#   'get',
#   'happy',
#   'grades',
#   'al',
#   '...'],
#  ['Grande'],
#  ['Manila_bro', 'chosen', 'follow', 'Twitter', 'Thanks', 'follow'],
#  ['sure',
#   'let',
#   'know',
#   "'re",
#   'around',
#   '..',
#   'side',
#   'world',
#   'u',
#   'take',
#   'care'],
#  ['top', 'new', 'followers', 'community', 'week'],
#  ['finally', 'fucking', 'weekend'],
#  ['REAL'],
#  ['thanks', 'D'],
#  ['Hi',
#   'BAM',
#   'Can',
#   'follow',
#   'bestfriend',
#   'She',
#   'loves',
#   'lot',
#   'See',
#   'Warsaw',
#   'lt',
#   'NUM',
#   'Love',
#   'lt',
#   'NUM',
#   'x45'],
#  ['YES',
#   'I',
#   'Joined',
#   'call',
#   'amp',
#   'gift',
#   'lt',
#   'NUM',
#   'Got',
#   'ta',
#   'Get',
#   'D'],
#  ['yeahhh'],
#  ['I', 'DM', 'amp', 'make', 'night', 'better'],
#  ['joined', 'Event', 'D', 'Might', 'get', 'Text', 'day', 'Luv', 'U'],
#  ['Would', 'really', 'appreciate', 'share', 'video', 'around'],
#  ['Hello', 'Get', 'Youth', 'Job', 'Opportunities', 'follow', 'gt', 'gt'],
#  ['oh', 'wow', 'That', 'beautiful', 'tom'],
#  ['Love', 'You'],
#  ['I',
#   'added',
#   'video',
#   'playlist',
#   'back',
#   'twitch',
#   'today',
#   'going',
#   'league',
#   'NUM',
#   'NUM'],
#  ['top', 'supports', 'community', 'week'],
#  ['follow', 'amp', 'follow', 'u', 'back'],
#  ['Gym', 'Monday', 'ca', "n't", 'wait', 'Likes'],
#  ['Hey', "'s", 'invite', 'join', 'Scope', 'influencer'],
#  ['Those', 'friends', 'know'],
#  ['waiting', 'nudes'],
#  ['go', 'sleep', 'u'],
#  ['Stats',
#   'day',
#   'arrived',
#   'NUM',
#   'new',
#   'follower',
#   'NO',
#   'unfollowers',
#   'via'],
#  ['My', 'birthday', 'week', 'today', 'D'],
#  ['I', 'want', "'re", 'T', 'shirts', 'They', 'cool', 'D'],
#  ['haw', 'phela', 'looking', 'like', 'Mom', 'obviously', 'looking', 'like'],
#  ['prince', 'charming', 'stage', 'x'],
#  ['really', 'good', 'luck'],
#  ['Stats',
#   'day',
#   'arrived',
#   'NUM',
#   'new',
#   'follower',
#   'NO',
#   'unfollowers',
#   'via'],
#  ['top', 'engaged', 'members', 'community', 'week'],
#  ['tylers', 'hipster', 'glasses', 'D'],
#  ['Hey', 'Marty', 'Glad', 'see', 'Twitter'],
#  ['Hi', 'joining', 'today'],
#  ['done', 'thanks'],
#  ['Its',
#   'already',
#   'afternoon',
#   'lets',
#   'read',
#   'Al',
#   'Kahfi',
#   'day',
#   'finish'],
#  ['OhmyG',
#   'yaya',
#   'dub',
#   'done',
#   'stalk',
#   'ig',
#   'accnt',
#   '..',
#   'GONDOOO',
#   'MOO',
#   'TOLOGOOO',
#   'HAHA'],
#  ['Here', "'s", 'invite', 'become', 'Scope', 'influencer', 'Details'],
#  ['top', 'influencers', 'community', 'week'],
#  ['thanks', 'zzz', 'xx'],
#  ['Physiotherapy', 'Friday', 'hashtag', 'today', 'Custom'],
#  ['know', 'I', '💪', 'Monica', 'I', 'miss', 'yeah', 'sounds', 'good'],
#  ['``', 'Good', 'morning', 'beautiful', '``', 'That', "'s", 'takes'],
#  ['Hi',
#   'BAM',
#   'Can',
#   'follow',
#   'bestfriend',
#   'She',
#   'loves',
#   'lot',
#   'See',
#   'Warsaw',
#   'lt',
#   'NUM',
#   'Love',
#   'lt',
#   'NUM',
#   'x43'],
#  ['oh',
#   'yeah',
#   'I',
#   'definitely',
#   'going',
#   'try',
#   'tonight',
#   'took',
#   'advice',
#   'We',
#   'Treviso'],
#  ['follow', 'amp', 'follow', 'u', 'back'],
#  ['Hi',
#   'Would',
#   'like',
#   'concert',
#   'Let',
#   'know',
#   'city',
#   'country',
#   'I',
#   "'ll",
#   'start',
#   'working',
#   'Thanks'],
#  ['Fine', '...', 'Have', 'gorgeous', 'Friday', 'friend', '..', 'xo', '..'],
#  ['Oven',
#   'roasted',
#   'garlic',
#   'olive',
#   'oil',
#   'sun',
#   'dried',
#   'tomatoes',
#   'dried',
#   'basil',
#   'century',
#   'tuna'],
#  ['Right', 'back', 'atchya', 'Have', 'great', 'day', 'everyone'],
#  ["n't", 'even', 'follow', 'back'],
#  ['The', 'future', 'almost'],
#  ['top', 'new', 'followers', 'community', 'week'],
#  ['No', 'chance'],
#  ['cheers'],
#  ['go', 'po', 'ice', 'cream'],
#  ['I', 'agree', 'NUM'],
#  ['hehehehe', 'point', 'p'],
#  ['next', 'time', 'stay', 'home'],
#  ['thanks'],
#  ['top', 'supports', 'community', 'week'],
#  ['soon', 'promise'],
#  ['Web', 'Whatsapp', 'volta', 'funcionar', 'com', 'iPhone', 'jailbroken'],
#  ['I',
#   'plan',
#   'watching',
#   'later',
#   'NUM',
#   'mins',
#   'Leia',
#   'appears',
#   'hologram',
#   'R2D2',
#   'w',
#   'message',
#   'Obi',
#   'Wan',
#   'sits',
#   'w',
#   'Luke'],
#  ['Inter', 'NUM', 'UCL', 'Arsenal', '...', 'Small', 'team', 'Right'],
#  ['Just',
#   'passing',
#   '🚂',
#   'Dewsbury',
#   'Railway',
#   'Station',
#   'DEW',
#   'Dewsbury',
#   'West',
#   'Yorkshire'],
#  ['NUM', 'smh'],
#  ["'s",
#   '9:25',
#   'I',
#   'live',
#   'Scotland',
#   "'s",
#   'strange',
#   'imagine',
#   'Megan',
#   'xx'],
#  ['A4', '....', 'Shweta', 'Tripathi', '.-', '..'],
#  ['NUM',
#   'Over',
#   'NUM',
#   'W',
#   'kurtas',
#   'And',
#   'Mom',
#   'half',
#   'number',
#   'I',
#   'D'],
#  ['Ah', 'Hello', 'back', 'Larry'],
#  ['Anyway', 'Friday', 'looking', 'kinda', 'gooood'],
#  ['follow', 'amp', 'follow', 'u', 'back'],
#  ['Lol', 'Well', 'That', "'s", 'life', 'thank', 'God', 'enn'],
#  ['surely', 'could', 'warmup', 'morning', 'Coming', 'Nth', 'Bath', 'xx'],
#  ['Dum',
#   'Dum',
#   'Andar',
#   'Ram',
#   'Sampath',
#   'Sona',
#   'Mohapatra',
#   'amp',
#   'Samantha',
#   'Edwards',
#   'Mein',
#   'Tulane',
#   'razi',
#   'razi',
#   'Wah',
#   'That',
#   "'s",
#   'Josh'],
#  ['always', 'smile'],
#  ['picture'],
#  ['Thanks', 'time', '16.20', 'right', 'That', "'s", 'perfect', 'timing'],
#  ['top', 'engaged', 'members', 'community', 'week'],
#  ['know'],
#  ['We',
#   'already',
#   'given',
#   'gas',
#   'subsidy',
#   'long',
#   'back',
#   'initiative',
#   'proposed',
#   '..',
#   'Feeling',
#   'delighted',
#   'done'],
#  ['I', 'missed', 'yesterday'],
#  ['Hi',
#   'BAM',
#   'Can',
#   'follow',
#   'bestfriend',
#   'She',
#   'loves',
#   'lot',
#   'See',
#   'Warsaw',
#   'lt',
#   'NUM',
#   'Love',
#   'lt',
#   'NUM',
#   'x42'],
#  ['lmaoo',
#   'The',
#   'best',
#   'songs',
#   'ever',
#   'lt',
#   'NUM',
#   'We',
#   'shall',
#   'little',
#   'throwback',
#   'week',
#   'p'],
#  ['go',
#   'outlying',
#   'islands',
#   'Cheung',
#   'Chau',
#   'Mui',
#   'Wo',
#   '....',
#   'totally',
#   'different'],
#  ['Kitchen', 'clean', 'I', "'m", 'totally', 'amazed'],
#  ['follow', 'amp', 'follow', 'u', 'back'],
#  ['cusp', 'testing', 'waters', 'hope', 'rewarding'],
#  ['top', 'influencers', 'community', 'week'],
#  ['arummzz', 'Let', "'s", 'go', '...', 'I', "'ll", 'drive', 'p', '…'],
#  ['Anyone', 'wan', 'na', 'skype', 'D'],
#  ['may', 'look', 'bit', 'real', 'nice', 'friendly', 'girl'],
#  ['I', 'like', 'But', 'pretend~'],
#  ['watching', 'concert', 'film'],
#  ['Congratulations',
#   "'re",
#   'winner',
#   'contest',
#   'Please',
#   'DM',
#   'us',
#   'address',
#   'contact',
#   'number'],
#  ['Have', 'great', 'weekend', 'guys'],
#  ['top', 'new', 'followers', 'community', 'week'],
#  ['cool', 'seeing', 'film', 'today'],
#  ['Check', 'Email', 'Marketing', '24/7', 'wo', "n't", 'regret', 'buy'],
#  ['LOL',
#   'Come',
#   'join',
#   'us',
#   '...',
#   'See',
#   'u',
#   'around',
#   'NUM',
#   'hours',
#   'u',
#   'leave',
#   'without',
#   'delays'],
#  ['Actually',
#   'easy',
#   'like',
#   'must',
#   'station',
#   'I',
#   'guess',
#   'train',
#   'wd',
#   'take',
#   'least',
#   'hour',
#   'shifting',
#   'engine',
#   'etc'],
#  ['sunburn', 'peeling'],
#  ['Visit', 'blog', 'thanks', 'D'],
#  ['Hi',
#   'Would',
#   'like',
#   'concert',
#   'Let',
#   'know',
#   'city',
#   'country',
#   'I',
#   "'ll",
#   'start',
#   'working',
#   'Thanks'],
#  ['talk', 'I', 'help'],
#  ['``',
#   'A',
#   'Huge',
#   'amp',
#   'Warm',
#   'Welcome',
#   '``',
#   '☆',
#   'finally',
#   'complete',
#   'triangle',
#   '☆'],
#  ['I', 'live', 'Northern', 'Ireland', 'sights', 'seen'],
#  ['follow', 'amp', 'follow', 'u', 'back'],
#  ['top', 'supports', 'community', 'week'],
#  ['Stats',
#   'day',
#   'arrived',
#   'NUM',
#   'new',
#   'follower',
#   'NO',
#   'unfollowers',
#   'via'],
#  ['feeling',
#   'smthng',
#   'smthng',
#   'fr',
#   'u',
#   '...',
#   'lol',
#   '...',
#   'wan',
#   'na',
#   'hug',
#   'u',
#   '....',
#   'XOXO',
#   '...',
#   'love',
#   'uu',
#   'jaann',
#   'take',
#   'care',
#   'lt',
#   'NUM',
#   '``'],
#  ['thanks', 'mom'],
#  ['Thanks', 'Happy', 'connect'],
#  ['wonderful',
#   'thing',
#   "'s",
#   'made',
#   'feel',
#   'fluffy',
#   'inside',
#   'Great',
#   'pirouette',
#   'Moose',
#   'D'],
#  ['I', 'trip', 'philly', 'December', 'I', "'d", 'love', 'come', 'dude'],
#  ['Hi',
#   'BAM',
#   'Can',
#   'follow',
#   'bestfriend',
#   'She',
#   'loves',
#   'lot',
#   'See',
#   'Warsaw',
#   'lt',
#   'NUM',
#   'Love',
#   'lt',
#   'NUM',
#   'x41'],
#  ['The', 'question', 'flawed', 'Pain', "n't", 'negate', 'strength'],
#  ['You', 'went', 'solo', 'moves', "n't", 'made', 'D'],
#  ['hey',
#   'fav',
#   'nirvana',
#   'song',
#   'smells',
#   'like',
#   'teen',
#   'spirit',
#   'rip',
#   'amy',
#   'winehouse'],
#  ['top', 'engaged', 'members', 'community', 'week'],
#  ['Let', "'s", 'go', '...', 'I', "'ll", 'drive', 'p', '…'],
#  ['name', 'couple', 'yet'],
#  ['I', 'love', 'goodnight', 'Vid', 'going', 'I', 'wake', 'love', 'one'],
#  ['This',
#   'weekend',
#   'I',
#   'gon',
#   'na',
#   'shoot',
#   'lovely',
#   'lt',
#   'NUM',
#   'Here',
#   'picture',
#   'I',
#   'made',
#   'last',
#   'time',
#   'D'],
#  ['anyway'],
#  ['Itty', 'Bitty', 'Teenie', 'Bikini', 'g'],
#  ['I', 'joined', 'Event', 'D', 'Might', 'get', 'Text', 'day', 'Luv', 'U'],
#  ['Always',
#   'much',
#   'fun',
#   'Nth',
#   'hour',
#   'gets',
#   'together',
#   'Ending',
#   'night',
#   'ice',
#   'cream',
#   'Xfiles',
#   'Content'],
#  ['easy', 'D'],
#  ['yes', 'surprised', "n't", 'see', 'bit', 'rain', 'today', '...'],
#  ['follow', 'amp', 'follow', 'u', 'back'],
#  ['To', 'fabulous', 'Friday', 'keep', 'fantastic', 'work'],
#  ['please',
#   'follow',
#   '♡',
#   '♡',
#   '♡',
#   '♡',
#   'please',
#   'jb',
#   'follow',
#   'I',
#   'love',
#   'always',
#   'forever',
#   'I',
#   "'m",
#   'belieber',
#   '♡',
#   '♡',
#   '♡',
#   '♡',
#   'I',
#   'love',
#   'u'],
#  ['top', 'influencers', 'community', 'week'],
#  ['Morning'],
#  ['good', 'hear'],
#  ['Nighty', 'night', 'Do', "n't", 'let', 'bed', 'bugs', 'bite', 'D'],
#  ['Very', 'beautiful', 'bracelet', 'good', 'idea'],
#  ['waiting', 'foundry', 'Where'],
#  ['I', 'like', 'game'],
#  ['Ah',
#   'Now',
#   'makes',
#   'sense',
#   '...',
#   'Did',
#   "n't",
#   'see',
#   'pic',
#   'effing',
#   'phone',
#   'last',
#   'night',
#   'Woot',
#   'x'],
#  ['Hi', 'Derek', 'could', 'try', 'using', 'ParkShare', 'Gloucestershire'],
#  ['Aaaahhh', 'man', 'track', 'traffic', 'stress', 'reliever'],
#  ['top', 'new', 'followers', 'community', 'week'],
#  ['How', "'re", 'today', 'dear'],
#  ['I', 'hear', 'guys', 'want', 'Arbeloa', 'D'],
#  ['turning',
#   'NUM',
#   'NUM',
#   'days',
#   '...',
#   'omg',
#   'least',
#   'NUM',
#   'years',
#   'difference'],
#  ['Well', 'say', 'Europe', 'rise', 'I', 'find', 'hard', 'believe'],
#  ['uncountable', 'coz', 'love', 'unlimited'],
#  ['Yes', 'course'],
#  ['yes', 'love'],
#  ['☕', '☕', '☕', 'Thank', 'Rita'],
#  ['Hi', 'could', 'please', 'DM', 'us', 'info', "'d", 'happy', 'help'],
#  ['way', 'boy'],
#  ['I', 'hope', 'get', 'lot', 'nice', 'gifts', 'D'],
#  ['Hi',
#   'BAM',
#   'Can',
#   'follow',
#   'bestfriend',
#   'She',
#   'loves',
#   'lot',
#   'See',
#   'Warsaw',
#   'lt',
#   'NUM',
#   'Love',
#   'lt',
#   'NUM',
#   'x40'],
#  ['top', 'supports', 'community', 'week'],
#  ['So', 'True'],
#  ['I',
#   'added',
#   'video',
#   'playlist',
#   'back',
#   'twitch',
#   'today',
#   'going',
#   'league',
#   'NUM',
#   'NUM'],
#  ['Sethi', 'HIGH'],
#  ['exe', 'skeem', 'saam'],
#  ['These', 'people', 'make', 'smile', 'K'],
#  ['Thanks', 'invite'],
#  ['polite',
#   'izzat',
#   'wese',
#   'trust',
#   'khawateen',
#   'k',
#   'sath',
#   'selfies',
#   'say',
#   'mana',
#   'kar',
#   'deya'],
#  ['Thank', "'s", 'Friday', 'evening', 'sorted'],
#  ['smart'],
#  ['nice', 'hair', 'tbh'],
#  ['NUM', 'years'],
#  ['jacob', 'amp', 'g', 'upgrade'],
#  ['Nice', 'tee', 'man'],
#  ['Happy', 'family', 'vacation', '..', 'D', 'pic', '—'],
#  ['sleep', 'would', 'nice'],
#  ['If', "'re", 'reading', "'re", 'beautiful', 'Like', 'read'],
#  ['Talking', 'One', 'person', '....', 'Having', 'Two', 'Conversations'],
#  ['skype', 'fun'],
#  ['online'],
#  ['...', "'s", 'Friday', 'D'],
#  ['top', 'engaged', 'members', 'community', 'week'],
#  ['Something', 'get', 'great', 'start', 'Have', 'great', 'day'],
#  ['follow', 'amp', 'follow', 'u', 'back'],
#  ['square', 'enix', 'bissmillah', 'ya', 'Allah'],
#  ["'re",
#   'training',
#   'startups',
#   'week',
#   'w/',
#   "'d",
#   'love',
#   'drop',
#   'arnd',
#   'town'],
#  ['Basically', 'piss', 'cup', 'test'],
#  ['next'],
#  ['also', 'Twitter', 'terrible', 'complicated', 'discussions'],
#  ['Snapchat', 'LynetteLowe'],
#  ['I', 'looking', 'forward', 'NUM', 'hour', 'shift', 'today'],
#  ['definately',
#   'agree',
#   "'s",
#   'growing',
#   'sport',
#   'Drop',
#   'email',
#   'details',
#   'see'],
#  ['My', 'last', 'rt'],
#  ['...', 'Rakyat', 'keep', 'visiting', 'blog', 'reading', 'writing'],
#  ['ever',
#   'since',
#   'I',
#   'mentioned',
#   'fly',
#   'fishing',
#   'day',
#   'I',
#   "'m",
#   'getting',
#   'follows',
#   'promoted',
#   'posts',
#   'lol',
#   'cyber',
#   'stalked'],
#  ['Proud', 'You', 'Papa', 'Coach'],
#  ['great', 'talking', 'D'],
#  ['never',
#   'see',
#   'positive',
#   'kha',
#   'u',
#   'could',
#   'also',
#   'mention',
#   'atleast',
#   'going'],
#  ['Hi',
#   'BAM',
#   'Can',
#   'follow',
#   'bestfriend',
#   'She',
#   'loves',
#   'lot',
#   'See',
#   'Warsaw',
#   'lt',
#   'NUM',
#   'Love',
#   'lt',
#   'NUM',
#   'x39'],
#  ['The',
#   'mango',
#   'lassi',
#   "'s",
#   'Monty',
#   "'s",
#   'marvellous',
#   'D.',
#   'Though',
#   'I',
#   'suspect',
#   "'s",
#   'meant',
#   '....'],
#  ['top', 'influencers', 'community', 'week'],
#  ['Haha',
#   'Yes',
#   'I',
#   'NUM',
#   'hrs',
#   'The',
#   'time',
#   'come',
#   'touch',
#   'Kepler',
#   '452b',
#   'Chalna',
#   'hai',
#   'D'],
#  ['follow', 'amp', 'follow', 'u', 'back'],
#  ['thankyou', 'pretty'],
#  ['definitely', 'Hazel', 'Food', 'Market', 'Brooklyn', 'Pta', 'gt', 'gt'],
#  ['still', 'awake'],
#  ['okayy', 'D'],
#  ['Awww', 'thank'],
#  ['ha',
#   'That',
#   'surprise',
#   'least',
#   'Okay',
#   'see',
#   'doc',
#   'afternoon',
#   'Yorkshire',
#   'splendid',
#   'though',
#   'xx'],
#  ['spam',
#   'folder',
#   'WOW',
#   'I',
#   'huge',
#   'amount',
#   'I',
#   'need',
#   'travel',
#   'Nigeria',
#   'claim'],
#  ['RTed', 'Good', 'Luck'],
#  ['My', 'legs', 'hurt', 'bad'],
#  ['I', 'get', 'mine', 'Saturday'],
#  ['thaaanks', 'December', 'puhon'],
#  ['happinessss~'],
#  ['True',
#   'Can',
#   'change',
#   'TnC',
#   'without',
#   'prior',
#   'notification',
#   'I',
#   'could',
#   'used',
#   'last',
#   'night'],
#  ['I', 'probably', 'find', 'funny', '2:22'],
#  ['Fat', 'cos', 'probably', 'ate', 'Yuna', 'D', 'D', 'D'],
#  ['Have', 'fun', 'Tameside'],
#  [],
#  ['you´re', 'welcome'],
#  ['My', 'Google+', 'account'],
#  ['call', 'scousers', 'everything', 'Hope', 'Zoe', 'well', 'mate'],
#  ['RIGHT',
#   'I',
#   'literally',
#   'like',
#   'maybe',
#   'u',
#   'get',
#   'people',
#   'actually',
#   'know',
#   "'re"],
#  ['||', 'Sameee~', 'Rest', 'well'],
#  ['happy',
#   'birthday',
#   'Edgar',
#   'I',
#   'hope',
#   'good',
#   'one',
#   'keep',
#   'updating',
#   'travel',
#   'log'],
#  ['Hello', 'D'],
#  ['bring', 'Abes'],
#  ['Stats',
#   'day',
#   'arrived',
#   'NUM',
#   'new',
#   'followers',
#   'NO',
#   'unfollowers',
#   'via'],
#  ['someone', 'talk'],
#  ['never', 'ever', 'meet', 'D'],
#  ['come', 'man', 'D', 'D'],
#  ['follow', 'amp', 'follow', 'u', 'back'],
#  ['Hi',
#   'BAM',
#   'Can',
#   'follow',
#   'bestfriend',
#   'She',
#   'loves',
#   'lot',
#   'See',
#   'Warsaw',
#   'lt',
#   'NUM',
#   'Love',
#   'lt',
#   'NUM',
#   'x38'],
#  ['sighs', 'dreamily', 'pout', 'come', 'bath', 'eyes'],
#  ['happy', 'birthday', 'love'],
#  ['Cheers'],
#  ['Funny', 'happened', 'Phil'],
#  ['I', "'d", 'call', "'em", 'Del', 'amp', 'Rodders', 'What', 'else'],
#  ['Hi', 'may', 'like', 'play', 'newest', 'gamejam', 'game', 'would', 'happy'],
#  ['This',
#   'great',
#   'Irish',
#   'literature',
#   'really',
#   'inaccessible',
#   'us',
#   'without',
#   'Irish'],
#  ['yeah', 'This', 'fun'],
#  ['Nice', 'music', 'Check'],
#  ['Strange',
#   'Kareena',
#   "'s",
#   'Fans',
#   'Not',
#   'Knowing',
#   'Kareena',
#   "'s",
#   'Fans'],
#  ['Hello', 'Get', 'Youth', 'Job', 'Opportunities', 'follow', 'gt', 'gt'],
#  ['better'],
#  ['Cool', 'Will', 'look'],
#  ['beautiful'],
#  ['I', "'m", 'playing', 'Brain', 'Dots'],
#  ['That',
#   "'s",
#   'fair',
#   'enough',
#   'I',
#   'would',
#   "n't",
#   'rush',
#   'back',
#   'either'],
#  ['Brandi', 'NUM', 'FB', 'DROP', 'A', 'SELFIE', 'fun'],
#  ['follow', 'amp', 'follow', 'u', 'back'],
#  ['During', 'carnival', 'men', 'put', 'masks', 'masks', 'Xavier', 'Forneret'],
#  ['Jennifer',
#   'Check',
#   'site',
#   'u',
#   'wan',
#   'na',
#   'get',
#   'FREE',
#   '50.000',
#   'NUM',
#   'Ball',
#   'Pool',
#   'Coins',
#   'Thank'],
#  ['Beautiful', 'edit', 'Trish', 'Loved', '♥'],
#  ['Gratefulness',
#   'Happiness',
#   'Post',
#   'three',
#   'things',
#   "'re",
#   'grateful',
#   'today',
#   'comments'],
#  ['Love', 'wakeup', 'beside', 'amp', 'real', 'dirty', 'dirty', 'sex'],
#  ['LMAOOO', 'SAME', 'hot', '😤', '😤', 'like', 'louis', "'s", 'hot'],
#  ['Just',
#   'gon',
#   'na',
#   'throw',
#   'idea',
#   'cause',
#   "'re",
#   'bad',
#   'inspire',
#   'think',
#   'something',
#   'much',
#   'better'],
#  ['The', 'Best', 'Twoofs', 'follow', 'GR8', 'wkend'],
#  ['I', 'wish', 'I', 'could', 'Maybe', 'one', 'year'],
#  ['hey', 'guys'],
#  ['I',
#   'think',
#   'I',
#   'need',
#   'go',
#   'bed',
#   'kind',
#   'exhausted',
#   'good',
#   'night',
#   'twitter'],
#  ['Thank', 'much', '..', 'So', 'glad', 'liked', '..'],
#  ['It', 'get', 'better', 'time'],
#  ['Kind', 'words', 'thank', 'much', 'It', "'s", 'much', 'good', 'area'],
#  ['Hi', 'beautiful', 'follow', 'please', 'NUM'],
#  ['They', 'n', '’', 'kale', 'crisps', 'Why', 'ruin', 'good', 'thing'],
#  ['Hi',
#   'BAM',
#   'Can',
#   'follow',
#   'bestfriend',
#   'She',
#   'loves',
#   'lot',
#   'See',
#   'Warsaw',
#   'lt',
#   'NUM',
#   'Love',
#   'lt',
#   'NUM',
#   'x37'],
#  ['Open', 'Worldwide'],
#  ['get', 'fuck', 'outta', 'D'],
#  ['Cool', 'guys', 'It', "'s", 'release', 'They', 'work'],
#  ['It', 'really', 'looks', 'Vantastic'],
#  ['Today', 'I', 'finally', 'time', 'work', 'Xcylin', 'D'],
#  ['Thank',
#   'So',
#   'bundle',
#   'shows',
#   'internet',
#   'price',
#   'phone',
#   'realisticly',
#   'paying',
#   'Net'],
#  ['True',
#   'Education',
#   'powerful',
#   'weapon',
#   'use',
#   'change',
#   'world',
#   "''",
#   'Nelson',
#   'Mandela'],
#  ['follow', 'amp', 'follow', 'u', 'back'],
#  ['Most',
#   'recent',
#   'trip',
#   'J',
#   'amp',
#   'K',
#   'totally',
#   'loved',
#   'D',
#   'And',
#   "'s",
#   'Chenab',
#   'flows',
#   'Pakistan'],
#  ['My'],
#  ['Caught', 'first', 'salmon', 'today', 'D'],
#  ['happy', 'Friday', 'Just', 'checking', 'see', 'enjoyed', 'Super', 'Blend'],
#  ['Thanks',
#   'following',
#   'Do',
#   'get',
#   'touch',
#   "'d",
#   'like',
#   'info',
#   'project'],
#  ['Please',
#   'go',
#   'check',
#   'awesome',
#   'friend',
#   "'s",
#   'stream',
#   'He',
#   "'s",
#   'fantastic',
#   'artist'],
#  ['My', 'Alma', 'Mater', 'Faith', 'Christian', 'School'],
#  ['Good', 'luck', 'upcoming', 'UK', 'appearances'],
#  ['Lol',
#   '😄',
#   '😄',
#   'really',
#   'I',
#   'ca',
#   "n't",
#   'believe',
#   'beautiful',
#   'girl',
#   'like',
#   'single',
#   'p'],
#  ['I', 'never', 'listening', 'The', 'Hills', 'every'],
#  ['would', 'listen', 'Beats', 'NUM', 'What', 'went', 'wrong', 'life'],
#  ['Haha', "'s", 'great'],
#  ['Getting',
#   'everything',
#   'ready',
#   'Natural',
#   'Pefumery',
#   'Workshop',
#   'Neals',
#   'Yard',
#   'Covent',
#   'Garden',
#   'tomorrow'],
#  ['fback', 'indo', 'harmos'],
#  ['Americano'],
#  ['Why', 'I'],
#  ['LOVE', 'way', 'lt', 'NUM'],
#  ['ALWAYS', 'Remember'],
#  ['Aww', 'Thank', 'Beautiful', 'pic', 'D'],
#  ['heads'],
#  ['Hi',
#   'Saw',
#   'u',
#   'follow',
#   'thought',
#   'u',
#   'might',
#   'like',
#   '``',
#   'Dark',
#   '``',
#   '.Plz',
#   'let',
#   'us',
#   'know',
#   'u',
#   'think'],
#  ['Smart', 'handshome', 'cute', 'juga', 'D'],
#  ['hurray', 'Looking', 'forward', 'meeting'],
#  ['follow', 'amp', 'follow', 'u', 'back'],
#  ['cause',
#   'hate',
#   'course',
#   'lol',
#   'I',
#   'ca',
#   'nt',
#   'decide',
#   'I',
#   'want',
#   'change',
#   'I',
#   'going',
#   'take',
#   'time',
#   'save',
#   'maybe',
#   'travel'],
#  ['It', "'s", 'list', 'I', "'m", 'still', 'show'],
#  [],
#  ['Hi',
#   'Would',
#   'like',
#   'concert',
#   'Let',
#   'know',
#   'city',
#   'country',
#   'I',
#   "'ll",
#   'start',
#   'working',
#   'Thanks'],
#  ['Oh', 'awesome', 'thank', 'much'],
#  ["'re", 'perfect'],
#  ['Hiya', 'email', 'web', 'exec', 'able', 'help'],
#  ['enjoy', 'photos', 'mom', 'baby'],
#  ['BIG', 'thx', 'NUM', 'kind', 'support', 'GOOD', 'LUCK'],
#  ['``',
#   'Chinas',
#   'actually',
#   'girl',
#   'That',
#   'homosexual',
#   '``',
#   '``',
#   'But',
#   'love',
#   'either',
#   'way',
#   '``',
#   'D'],
#  ['cause', 'likes', 'Lot'],
#  ['give', 'time', 'fam', 'I', 'got', 'things', 'mind'],
#  ['Thanks', 'God', "'s", 'friday'],
#  ['lovely'],
#  ['NUM', 'Not', 'quite', 'sure', 'radio', 'set', 'heart'],
#  ['Hiii', 'Jack', 'ily', '✨', '✨', '✨'],
#  ['I',
#   'played',
#   'dominoes',
#   'pub',
#   'It',
#   'got',
#   'quite',
#   'heated',
#   'Enjoyed',
#   'though',
#   'D'],
#  ['prob'],
#  ['Enjoy', 'And', 'sorry', 'hastily', 'typed', 'message'],
#  ['thank'],
#  ['Can',
#   'I',
#   'say',
#   'big',
#   'thank',
#   'person',
#   'came',
#   'idea',
#   'screenshotting'],
#  ['We', 'true', 'Pakistanis', 'p'],
#  ['...', 'mention'],
#  ['Hi',
#   'BAM',
#   'Can',
#   'follow',
#   'bestfriend',
#   'She',
#   'loves',
#   'lot',
#   'See',
#   'Warsaw',
#   'lt',
#   'NUM',
#   'Love',
#   'lt',
#   'NUM',
#   'x36'],
#  ['3Points', 'Gooo', 'BAILEY'],
#  ['Thank'],
#  ['You', 'drank'],
#  ['old', 'pic'],
#  ['follow', 'amp', 'follow', 'u', 'back'],
#  ['I', "n't", 'gotten', 'sleep', 'I', 'NUM', '1/2', 'hours'],
#  ['Off', 'today', 'Yippee'],
#  ['done'],
#  ['HAPPY',
#   'BIRTHDAY',
#   'BABY',
#   '💟',
#   '💟',
#   'I',
#   'MISS',
#   'YOU',
#   'SO',
#   'MUCH',
#   'AND',
#   'LOVE',
#   'YOU',
#   'SO',
#   'MUCH'],
#  ['thanks', 'bro', 'D', 'x'],
#  ['lord'],
#  ['Sweet'],
#  ['We', 'like', 'Michael', 'Thanks', 'kind', 'words', 'Cheers', 'Em'],
#  ['Morning',
#   'Not',
#   'really',
#   'D',
#   'U',
#   "'re",
#   'already',
#   'fun',
#   'cause',
#   'weekend',
#   'right',
#   'D',
#   'ure',
#   'future',
#   'Have',
#   'amazing',
#   'night'],
#  ['Waiting', 'people', 'call', 'BIGOT', 'p'],
#  ['It', 'usually', 'Are', 'front', 'back', 'squats'],
#  ['much',
#   'fun',
#   'really',
#   'enjoyed',
#   'hope',
#   'next',
#   'contest',
#   'coming',
#   'soon'],
#  ['Dobar', 'dan', 'The', 'Brand', 'New', 'Heavies'],
#  ['looks',
#   'like',
#   'great',
#   'way',
#   'spend',
#   'Friday',
#   'afternoon',
#   'Enjoy',
#   'marathon',
#   'iflix'],
#  ['If', 'need', 'someone', 'talk', 'I', 'always', 'Keep', 'head'],
#  ['Officially', 'Graduated', 'D'],
#  ['I', "'m", 'glad', 'D', 'Did', 'cry'],
#  ['thanks'],
#  ['yep', 'expert', 'bisexuality', 'Good', 'luck'],
#  ['minal', 'aidzin', 'yo', 'pi', 'D'],
#  ['follow', 'amp', 'follow', 'u', 'back'],
#  ['The',
#   'plan',
#   'read',
#   'brand',
#   'new',
#   'cook',
#   'book',
#   'figure',
#   'make',
#   'dinner',
#   'tonight'],
#  ['lol',
#   "'s",
#   'tough',
#   'choice',
#   'tbh',
#   'really',
#   'like',
#   'every',
#   'song',
#   'others',
#   'p'],
#  ['welcome', '...'],
#  ['chill',
#   'SMU',
#   'oval',
#   'D',
#   "'Coz",
#   'I',
#   'basketball',
#   'player',
#   'Whahahaha'],
#  ['The',
#   'moment',
#   'I',
#   'decide',
#   'log',
#   'onto',
#   'account',
#   'I',
#   "n't",
#   'years',
#   'moment',
#   'I',
#   'saw',
#   'best',
#   'thing',
#   'ever'],
#  ['A5', 'If', 'I', 'Girl', 'My', 'Wardrobe', 'would', '``', 'W', '``'],
#  ['new', 'user'],
#  ['Welcome', 'back'],
#  ['oh',
#   'apparently',
#   'I',
#   "'m",
#   'already',
#   'member',
#   'Lol',
#   'Hopefully',
#   'able',
#   'come',
#   'depends',
#   'time',
#   'D'],
#  ['greatly', 'appreciated'],
#  ['hi', 'made', 'changes', 'design', 'hope', 'like'],
#  ['ahhh', 'yes', 'D'],
#  ['Nth',
#   'CinePambata',
#   'Video',
#   'Festival',
#   'Complete',
#   'mechanics',
#   'official',
#   'entry',
#   'form',
#   'may',
#   'downloaded',
#   'Sali',
#   'na',
#   'D'],
#  ['Hello', 'Get', 'Youth', 'Job', 'Opportunities', 'follow', 'gt', 'gt'],
#  ['follow', 'amp', 'follow', 'u', 'back'],
#  ['ur', 'moms', 'getting', 'u', 'swishers', 'ur', 'copping', 'Monday'],
#  ['My',
#   'Song',
#   'Week',
#   'Ducktails',
#   'Surreal',
#   'Exposure',
#   'Jingly',
#   'jangly',
#   'loveliness'],
#  ['It',
#   "'s",
#   'tomorrow',
#   'Are',
#   'followers',
#   'going',
#   'Come',
#   'say',
#   'hello',
#   'stand',
#   'High',
#   'Street'],
#  ['Good', 'luck', 'assessments', 'today'],
#  ['mental', 'strength', 'D'],
#  ['Looking',
#   'beautiful',
#   'You',
#   'amazing',
#   'body',
#   'YOu',
#   'ooze',
#   'sex',
#   'appeal',
#   'xx'],
#  ['HOME',
#   'AmassiveoverdoseofshipS',
#   'latest',
#   'vid',
#   'way',
#   '..',
#   'enjoy',
#   'visit',
#   'site',
#   '..'],
#  ['ISIS', 'Chan', 'D'],
#  ['T', 'amp', 'C', 'noted'],
#  ['Stats',
#   'day',
#   'arrived',
#   'NUM',
#   'new',
#   'follower',
#   'NO',
#   'unfollowers',
#   'via'],
#  ['Thanks', 'follow', 'Gemma', 'enjoy', 'New', 'Orleans'],
#  ['finally', 'caught', '\\o/', '\\o/', '\\o/', '..'],
#  ['It', 'funny', 'next', 'anime', 'Umaru', 'D'],
#  ['great', 'singer'],
#  ['follow', 'amp', 'follow', 'u', 'back'],
#  ['looks', 'like', 'GAME', 'ships', 'US', 'Got', 'order'],
#  ['takes', 'room', 'amp', 'car', 'I', "'m", 'gone', 'cool'],
#  ['going', 'streaming', 'soon'],
#  ['thanks'],
#  ['Hi',
#   'Would',
#   'like',
#   'concert',
#   'Let',
#   'know',
#   'city',
#   'country',
#   'I',
#   "'ll",
#   'start',
#   'working',
#   'Thanks'],
#  ['Hahaha',
#   'everyone',
#   'fun',
#   'story',
#   'related',
#   'song',
#   'We',
#   'got',
#   'labeled',
#   'worst',
#   'batch',
#   'principal',
#   'due',
#   'p'],
#  ['get',
#   'stuff',
#   'like',
#   'March',
#   'Release',
#   'one',
#   'first',
#   'starting',
#   'new',
#   'one'],
#  ['TOP', 'Twoofs', 'Wooftastic', 'Wkend', 'Guys'],
#  ['Well', 'received', 'necessary'],
#  ['long', 'time', 'see', 'p'],
#  ['I', "'ll", 'regret', 'rn', 'tomorrow', 'morning', 'whatever'],
#  ['That', 'hat', 'D'],
#  ['thank'],
#  ['never', 'love', 'life', 'success'],
#  ['abstinence'],
#  ['Then',
#   '``',
#   'Wtf',
#   'never',
#   'happened',
#   '``',
#   'moments',
#   'may',
#   'may',
#   'like',
#   'But',
#   "'s",
#   'surprise',
#   'thrown',
#   'D'],
#  ['Start', 'middle', 'finished'],
#  ['I', 'back', 'Twitter', '..'],
#  ['ended', 'happy'],
#  ['Lovely',
#   'stuff',
#   'This',
#   'needs',
#   'repeated',
#   'relentlessly',
#   'approximately',
#   'next',
#   'NUM',
#   'years'],
#  ['hug', 'many'],
#  ['OldSchool', 'Runescape'],
#  ['Thanks', 'shout', 'Have', 'wonderful', 'weekend'],
#  ['REST', 'DAY'],
#  ['LOVELY', 'DAAAY', 'D'],
#  ['lt', 'NUM', 'lt', 'NUM', 'lt', 'NUM', 'aLL', '—', 'feeling', 'blessed'],
#  ['I', 'sense'],
#  ['Awww', 'pussycats', 'xx'],
#  ['hope', 'everything', 'going', 'great', 'lol'],
#  ['Market', 'Main', 'launched', 'Pretoria'],
#  ['Do', 'I', 'care', 'I', 'care', '...', 'D'],
#  ['Tykkäsin',
#   '-videosta',
#   '200sub',
#   'special',
#   '15e',
#   'PaysafeCard',
#   'Giveaway',
#   'LUE',
#   'DESC'],
#  ['NUM', 'months', 'waiting', 'I', 'finally', 'hoodie', 'eeeep', 'Yay'],
#  ['mmmmmm', 'I', 'c', 'lovely', 'azz', 'sets', 'babe'],
#  ['thx', 'feedback', 'Glad', 'gained', 'value'],
#  ['good',
#   'night',
#   'lovely',
#   'I',
#   'hope',
#   'peaceful',
#   'nights',
#   'rest',
#   'feel',
#   'refreshed',
#   'wake',
#   'sweet',
#   'dreams'],
#  ['I', "'ll", 'never', 'get', 'used', 'thank', 'much'],
#  ['Thanks', 'Manthan', 'Stay', 'tuned', 'us'],
#  ['Freshness',
#   'beautiful',
#   'smile',
#   'mother',
#   'amp',
#   'determination',
#   'make',
#   'day'],
#  ['I', "'m", 'playing', 'Brain', 'Dots'],
#  ['PLEASE',
#   'JAMES',
#   'WHAT',
#   'YOU',
#   'THINK',
#   'OF',
#   'MY',
#   'BEAUTIFUL',
#   'GIRLS',
#   'ARE',
#   'THE',
#   'LONELIEST',
#   'TATTOO',
#   'You',
#   'changed',
#   'life'],
#  ['Hi', 'Girls', '.wish', 'Happy', '.and', 'W', 'E.', '♡', '♥', '♡', '♥'],
#  ['achieved',
#   'together',
#   'Thank',
#   'Rashmi',
#   'time',
#   'dedication',
#   'complete',
#   'inspiration'],
#  ['weekend', 'nearly'],
#  ['I', 'retweeted'],
#  ['It',
#   'updated',
#   'soon',
#   'I',
#   "'m",
#   'sure',
#   'If',
#   'sign',
#   'set',
#   'text',
#   'alerts',
#   '|DA'],
#  ['Something', 'new', 'D'],
#  ['Dang', 'rad', 'D'],
#  ['CHEERS'],
#  ['Massive',
#   'congrats',
#   'Niamh',
#   'Fennell',
#   'Journalism',
#   'Graduate',
#   'Lands',
#   'Dream',
#   'Job',
#   'Copying',
#   'amp',
#   'Pasting',
#   'Tweets'],
#  ['Thank'],
#  ['Stats',
#   'day',
#   'arrived',
#   'NUM',
#   'new',
#   'followers',
#   'NO',
#   'unfollowers',
#   'via'],
#  ['Yesss', 'I', 'thank', 'D'],
#  ['I',
#   'Ariana',
#   'grande',
#   'Selena',
#   'Gomez',
#   'Louis',
#   'tomlinson',
#   'Rita',
#   'Liam',
#   'Payne',
#   'Caradelevingne',
#   '🌷',
#   'I',
#   'trade',
#   'solo',
#   'dm'],
#  ['tired', 'But', 'fine'],
#  ['Nope', 'definitely', 'still', 'apply', 'year', 'want', 'D'],
#  ['Ah', 'found', 'thanks'],
#  ['aftie', 'p'],
#  ['Goodmorning'],
#  ['follow', 'amp', 'follow', 'u', 'back'],
#  ['’', 'EXACTLY', 'look', 'I', '’', 'going', 'D'],
#  ['Koel',
#   'Mallick',
#   'recites',
#   '``',
#   'National',
#   'Anthem',
#   '``',
#   'On',
#   'Day-6'],
#  ['Mon27July', 'UK', 'amp', 'Thur30July', 'ITV'],
#  ['For', '...'],
#  ['Only',
#   'one',
#   'leg',
#   'September',
#   'So',
#   'perhaps',
#   'BB',
#   'promote',
#   'full',
#   'album',
#   'September',
#   'D'],
#  ['I',
#   'still',
#   'fully',
#   'intend',
#   'write',
#   'many',
#   'game',
#   'designs',
#   'possible',
#   'And',
#   'attack',
#   'plan',
#   'next',
#   'NUM',
#   'months',
#   'gt',
#   'D'],
#  ['To', 'birds', 'come', 'join', 'us', 'little', 'fun'],
#  ['hope', 'clears', 'wkend', 'good', 'one'],
#  ['time', 'sleep'],
#  ['That', "'s", 'three', 'words', 'But', "'s", 'Rohit', 'D'],
#  ['gorgeous', 'queen', '....', 'god'],
#  ['The', 'long', 'wait'],
#  ['If',
#   "n't",
#   'get',
#   'inspired',
#   'sheer',
#   'fact',
#   'Obama',
#   'beat',
#   'innumerable',
#   'odds',
#   'become',
#   'US',
#   'President',
#   'ni',
#   'shauri',
#   'yako'],
#  ['Everyone', 'go', 'drop', 'follow', 'stream', 'D', 'K'],
#  ['Happy',
#   'Birthday',
#   'sunday',
#   'Hope',
#   'great',
#   'day',
#   'lots',
#   'pampering',
#   'love'],
#  ["t'was", 'great', 'thank'],
#  ["'m",
#   'going',
#   'cabincrew',
#   'interview',
#   'langkawi',
#   'Nth',
#   'august',
#   'please',
#   'wish',
#   'luck'],
#  ['Thank', 'You', 'D'],
#  ['I', 'fulfil', 'fantasies', '👉', '👈', '💖'],
#  ['cool', 'thanks', 'thinking', 'hope', 'well'],
#  ['follow', 'amp', 'follow', 'u', 'back'],
#  ['thank', 'much', 'babe', 'D'],
#  ['NUM', 'ex', 'twelebs', 'side', 'please'],
#  ['thanks', 'bro', 'D', 'x'],
#  ['great', 'day', 'D'],
#  ['Makes', 'much', 'sense', 'D', 'LOL'],
#  ['..', 'wait'],
#  ['Have', 'great', 'weekend'],
#  ['family', 'gt', 'gt', 'friends'],
#  ['An', 'apartment', 'makeover', 'great', 'ideas', 'factory', 'living'],
#  ['thanks', 'amp', 'welcome', 'hope', 'goes', 'brilliantly'],
#  ['Happyyyyyy', 'Birthdaaaaayyyy'],
#  ['come', 'kill'],
#  ['hi',
#   'interested',
#   'internship',
#   'program',
#   'But',
#   'sadly',
#   'I',
#   'ca',
#   'nt',
#   'access',
#   'Career',
#   'Page',
#   'Can',
#   'u',
#   'help',
#   'issue'],
#  ['Its',
#   'sad',
#   'hear',
#   'thank',
#   'much',
#   'overwhelmingly',
#   'beautiful',
#   'games',
#   'thank',
#   'hard',
#   'work'],
#  ['aha', 'yesss', 'Who', 'looking', 'forward', 'seeing'],
#  ['Happy', 'Friday', 'beauts', '♬'],
#  ['We', 'love', 'help', '/E'],
#  ['would', 'love', 'win', 'deo', 'faaaaaabulous', 'D', 'xx'],
#  ['Yes', 'John'],
#  ['Thanks', 'No', 'worries', 'I', "'ll", 'navigate', 'blog', 'check'],
#  ['thnks', 'progrmr'],
#  ['bet',
#   'Well',
#   'I',
#   'wo',
#   "n't",
#   'getting',
#   'sleep',
#   "'s",
#   'NUM',
#   'pm',
#   'shift',
#   'NUM',
#   "'s",
#   'quit',
#   'hard',
#   'work',
#   'But',
#   'thank',
#   'xx'],
#  ['figures'],
#  ['hardly', 'surprising', 'roses', 'inspire', 'much', 'emotive', 'poetry'],
#  ['followed'],
#  ['I', 'joined', 'program'],
#  ['I', 'always', 'end', 'breaking', 'apologizing', 'I', "n't", 'fuck', 'nice'],
#  ['Fabulous', 'Well', 'hope', 'great', 'day', '^KB'],
#  ['Hi',
#   'Would',
#   'like',
#   'concert',
#   'Let',
#   'know',
#   'city',
#   'country',
#   'I',
#   "'ll",
#   'start',
#   'working',
#   'Thanks'],
#  ['You', "'re", 'welcome'],
#  ['Visit', 'blog', 'thanks', 'D'],
#  ['Did', 'enjoy', 'Share', 'us', 'experience'],
#  ['follow', 'amp', 'follow', 'u', 'back'],
#  ['I', 'luv', 'urs'],
#  ['I', 'past', 'A', 'hoodie', 'covers', 'lot', 'sins'],
#  ['bet', 'excited', 'xxxxxxx', 'good', 'luck', 'hope', 'get', 'number', 'one'],
#  ['You',
#   "'re",
#   'welcome',
#   'Jim',
#   'Made',
#   'chuckle',
#   'train',
#   'morning',
#   'Happy',
#   'Friday'],
#  ['Shopping', 'bit', 'p'],
#  ['agreed', 'haha', 'p'],
#  ['Happy', 'Birthday', 'We', "'re", 'positive', 'full', 'cake'],
#  ['Doh',
#   'NUM',
#   'Subscribers',
#   'needed',
#   'Please',
#   'let',
#   'us',
#   'know',
#   'reached',
#   'number'],
#  ['I', "'m", 'good', 'thanks', 'hope', 'well', 'xx'],
#  ['Dry', 'hot', 'scorching', 'summer'],
#  ['Maybe', 'younger', 'woman', 'stamina', 'Tom', 'gt'],
#  ['things',
#   "n't",
#   'looking',
#   'great',
#   'either',
#   'expect',
#   'anything',
#   'less',
#   'lol',
#   'At',
#   'least',
#   "'s",
#   'weekend'],
#  ['Finally', 'get', 'bed', 'good', 'night', 'tweeties'],
#  ['Thanks', 'guys'],
#  ['FAB', 'Thank', 'support'],
#  ['I', 'really', 'nt', 'I', 'love', 'much'],
#  ['follow', '--', 'gt', '``', 'NUM', 'loners', 'side', 'please', '``', '``'],
#  ['charger'],
#  ['This'],
#  ['Introducing',
#   'new',
#   'word',
#   'vs.',
#   'altering',
#   'understanding',
#   'word',
#   'x',
#   'spreading',
#   'either',
#   'The',
#   'Big',
#   'Problem'],
#  ['follow', 'amp', 'follow', 'u', 'back'],
#  ['Wooftastic', 'TWOOFS', 'hope', 'supa', 'dupa', 'weekend'],
#  ['near', 'enough', 'Dartmoor'],
#  ['I',
#   "'m",
#   'gon',
#   'na',
#   'stay',
#   'gold',
#   'colour',
#   'Hopefully',
#   'come',
#   'soon',
#   'Thank',
#   'anyway'],
#  ['Follow', 'back'],
#  ['yay', 'ok', 'D'],
#  ['Someday', "'ll", 'know'],
#  ['U', 'r', 'dii', 'n', 'ca', 'nt', 'forget', 'Sis'],
#  ['Jgh', 'fr', 'smf', 'amp', 'Ft', 'W/', 'My', 'girl', 'lt', 'NUM'],
#  ['maybe',
#   'get',
#   'japanese',
#   'import',
#   'hello',
#   'kitty',
#   'matching',
#   'stationary'],
#  ['The', 'weekend', 'drawing', 'close', 'What', 'plans', 'D'],
#  ['Hi',
#   'Saw',
#   'u',
#   'follow',
#   'thought',
#   'u',
#   'might',
#   'like',
#   '``',
#   'Dark',
#   '``',
#   '.Plz',
#   'let',
#   'us',
#   'know',
#   'u',
#   'think'],
#  ['AND', 'HELLO', 'TWITTER', 'MY', 'ACCOUNT', 'IS', 'BROKEN', 'AGAIN'],
#  ['Hi',
#   'thanks',
#   'connecting',
#   'We',
#   'specialise',
#   'thermal',
#   'imaging',
#   'surveys',
#   '–',
#   'need',
#   'us'],
#  ['nice'],
#  ['Please', 'follow', 'back', 'x', 'NUM'],
#  ['Hi',
#   'I',
#   'want',
#   'get',
#   'connected',
#   'I',
#   'planning',
#   'come',
#   'South',
#   'Korea'],
#  ['oh', 'FACTS', 'p'],
#  ['I',
#   "'d",
#   'planned',
#   'nice',
#   'scamper',
#   'I',
#   'slept',
#   'alarm',
#   'For',
#   'two',
#   'hours',
#   'I',
#   'suppose',
#   'I',
#   'needed',
#   'sleep',
#   'I',
#   'ai',
#   "n't",
#   'mad'],
#  ['Chweina',
#   '...',
#   'xD',
#   'Jotzh',
#   'D',
#   'Dude',
#   '...',
#   'go',
#   'school',
#   "n't",
#   'waste',
#   'time',
#   'twitter'],
#  ['hiya',
#   'Yep',
#   'show',
#   'takes',
#   'place',
#   'completely',
#   'cover',
#   'Worth',
#   'bringing',
#   'coat',
#   'beforehand',
#   'tho',
#   'FOH',
#   'outside'],
#  ['thanks'],
#  ['enjoy', 'holiday', 'D'],
#  ['I',
#   "n't",
#   'seen',
#   'many',
#   'menacing',
#   'since',
#   'I',
#   'finished',
#   'JoJo',
#   'D'],
#  ['Ta'],
#  ['Thank',
#   'always',
#   'At',
#   'last',
#   'I',
#   '’',
#   'back',
#   'track',
#   'Hope',
#   'fantastic',
#   'weekend'],
#  ['make', 'better', 'though'],
#  ['Stats',
#   'day',
#   'arrived',
#   'NUM',
#   'new',
#   'follower',
#   'NO',
#   'unfollowers',
#   'via'],
#  ['accepted'],
#  ['follow', 'amp', 'follow', 'u', 'back'],
#  ['I', 'go', 'guys', 'Hope', 'enjoyed', 'updates', 'Bye', 'Admin', 'LuKris'],
#  ['Have', 'lovely', 'day', 'yes', 'Stay', 'happy', '😘'],
#  ['What', 'day'],
#  ['Happy',
#   'birthday',
#   'momma',
#   'bear',
#   'Love',
#   'much',
#   '❤',
#   '️',
#   'I',
#   'redid',
#   'I',
#   'found',
#   'last',
#   'picture',
#   'Nth',
#   'grade'],
#  ['K', 'I', "'ll", 'text', 'tomorrow'],
#  ['x'],
#  ['I', 'love', 'u.', 'p'],
#  ['nice', 'line'],
#  ['Playing', 'ATM'],
#  ['Appreciate', 'recent', 'Retweets', 'Have', 'great', 'Friday'],
#  ['follow', 'amp', 'follow', 'u', 'back'],
#  ['``',
#   'Building',
#   'product',
#   'like',
#   'packing',
#   'suitcase',
#   'Plan',
#   'think',
#   'need',
#   'Then',
#   'remove',
#   'half',
#   '``',
#   'Fully',
#   'agree'],
#  ['hang', 'copying', 'A', 'TRANSLATION', 'Dostoevsky', "'s", 'Notes', '..'],
#  ['voucher', '...', 'new', 'bugatti', "'s", 'value', 'D'],
#  ['Someone', 'loves', 'I', 'promise'],
#  ['``', 'I', 'know', 'bra', 'knows', 'bra', 'get', 'D'],
#  ['مطعم_هاشم', 'yummy', 'A7la', 'bdayt', 'season', 'mnwreeen'],
#  ['I', 'listen', 'jazz', 'truck'],
#  ['Hi',
#   'BAM',
#   'Can',
#   'follow',
#   'bestfriend',
#   'She',
#   'loves',
#   'lot',
#   'See',
#   'Warsaw',
#   'lt',
#   'NUM',
#   'Love',
#   'lt',
#   'NUM',
#   'x34'],
#  ['ca', "n't", 'wait', 'speak', 'See'],
#  ['Waiting',
#   'HQ',
#   'pic',
#   'today',
#   'add',
#   'YoonA',
#   'x',
#   'Hairpin',
#   'OTP',
#   'collection',
#   'D'],
#  ['honey', 'D'],
#  ['I', 'paindo', "n't", 'want', 'say', 'p'],
#  ['sure'],
#  ['awesome', 'I', 'await', 'report', 'D'],
#  ['throwback', 'lol', 'Manny', 'still', 'asshole'],
#  ['G+6',
#   'stories',
#   'structure',
#   'NUM',
#   'units',
#   'encompasses',
#   'NUM',
#   'NUM',
#   'BHK',
#   'Flats',
#   'D',
#   '+91',
#   'NUM',
#   'NUM',
#   'NUM'],
#  ['honored'],
#  ['You', 'know', 'like', 'D'],
#  ['follow', 'amp', 'follow', 'u', 'back'],
#  ['It', '``', 'Currys', '``', 'They', 'close', 'home'],
#  ['The', 'Clash', '``', 'Milano', 'Calling', '👌', '``'],
#  ['followback', 'po', '-D'],
#  ['legit', 'loser', 'sit', 'get', 'gassed'],
#  ['All',
#   'friends',
#   'hi',
#   'I',
#   'saw',
#   'dead',
#   'thing',
#   'made',
#   'think',
#   'aww',
#   'thanks',
#   'guys',
#   'D'],
#  ['speak'],
#  ['always'],
#  ['⭐', 'Can', 'I', 'please', 'get', 'follow', 'You', 'awesome'],
#  ['Awwww', 'thanks'],
#  ['Thanks', 'news', 'man', 'UTC'],
#  ['Remember',
#   'one',
#   'time',
#   'I',
#   "n't",
#   'go',
#   'flume',
#   'kaytranada',
#   'alunageorge',
#   'even',
#   'though',
#   'I',
#   'tickets',
#   'I',
#   'still',
#   'want',
#   'kms'],
#  ['oh', 'good', 'haha', 'let', 'know', 'think'],
#  ['thanks',
#   'NUM',
#   'give',
#   'certainty',
#   'problem',
#   'Hope',
#   'u',
#   'could',
#   'solve',
#   'faster',
#   '👊',
#   'At',
#   'least',
#   'know',
#   'nt',
#   'hurry',
#   'NUM',
#   'totem'],
#  ['Off', 'somewhere', 'later'],
#  ['Some', 'good', 'advice', 'Friday'],
#  ['Cheers', 'Alice'],
#  ['Here', 'go', 'please', 'click', 'link', 'checkout'],
#  ['Two', 'dogs', 'amp', 'One', 'Cat', 'good', 'friends'],
#  ['Ugh', 'I', "'ve", 'never', 'Rt', 'fade', 'moaning', 'Leeds', 'tweets'],
#  ['Looking', 'forward', 'Jozi', 'guys'],
#  ['hello', 'D', 'found', 'time', 'nt', 'following', 'till'],
#  ['I',
#   'THINK',
#   'THIS',
#   'IS',
#   'FROM',
#   'THEIR',
#   'FIFTH',
#   'ALBUM',
#   'IM',
#   'OKAY',
#   'FUCK'],
#  ['may', 'available', 'tix', 'pa', 'ba', 'ng', 'ATL', 'concert', 'Thanks'],
#  ['yeah',
#   'I',
#   'NUM',
#   'coldplay',
#   'songs',
#   'playlist',
#   'p',
#   'I',
#   'love',
#   'My',
#   'favorites',
#   'The',
#   'Scientist',
#   'Fix',
#   'You',
#   'Yellow',
#   'Atlas',
#   'p'],
#  ['awesome', 'I', "'ll", 'waiting'],
#  ['follow', 'amp', 'follow', 'u', 'back'],
#  ['done', 'yein'],
#  ['Haha', 'Receiving', 'thing', 'Friday', 'nice', 'way', 'start', 'day', 'xx'],
#  ['lol', 'selos'],
#  ['Ans.7', 'gt', 'Timely', 'Arrival'],
#  ['Waiter', 'bill', 'sir', 'Customer', 'Ok', 'kitchen', 'D'],
#  ['title', 'says', 'D'],
#  ['hey', "'s", 'almost', 'time', 'visit', 'city'],
#  ['So', 'keep', 'inside', 'pocket', 'ur', 'wripped', 'jeans'],
#  ['How', 'beautiful'],
#  ['well', 'haha', 'D'],
#  ['I',
#   'love',
#   'Connie',
#   "'s",
#   'fabulous',
#   'ship',
#   'amazing',
#   'crew',
#   'staff',
#   'Have',
#   'great',
#   'time'],
#  ['Hi',
#   'Sweetan',
#   'It',
#   "'s",
#   'best',
#   'ask',
#   'Have',
#   'great',
#   'day',
#   'fun',
#   'filming'],
#  ['nope'],
#  ['That', "'s", 'ok', 'thanks', 'following'],
#  ['mum', 'begging', 'watch', 'sopranos', "'ll", 'watch'],
#  ['Follow', 'back', 'please'],
#  ['oh', 'fun'],
#  ['That', "'s", 'great', 'hear', 'D'],
#  ['I', 'also'],
#  ['Hi',
#   'BAM',
#   'Can',
#   'follow',
#   'bestfriend',
#   'She',
#   'loves',
#   'lot',
#   'See',
#   'Warsaw',
#   'lt',
#   'NUM',
#   'Love',
#   'lt',
#   'NUM',
#   'x33'],
#  ['follow', 'please', 'Olly'],
#  ['This',
#   'beautiful',
#   'via',
#   'talented',
#   'elmoprinssi',
#   'Do',
#   "n't",
#   'forget',
#   '…'],
#  ['Bit',
#   'tired',
#   'NUM',
#   'hours',
#   'salsa',
#   'dancing',
#   'last',
#   'night',
#   'definitely',
#   'worth',
#   'Happy',
#   'Friday',
#   'everyone'],
#  ['thanks', 'haha', 'tell', 'truth'],
#  ['yes', 'pls'],
#  ['I',
#   'gotten',
#   'least',
#   'NUM',
#   'hours',
#   'sleep',
#   'past',
#   'NUM',
#   'NUM',
#   'days',
#   'rest',
#   'week',
#   'interesting',
#   ':3'],
#  ['Thank'],
#  ['Check',
#   'bro',
#   'Nth',
#   'blogiversary',
#   'Many',
#   'awesome',
#   'reviews',
#   'come',
#   'D',
#   '...'],
#  ['With', 'top', 'cutie', 'Bohol'],
#  ['follow', 'amp', 'follow', 'u', 'back'],
#  ['This',
#   'briliant',
#   'Was',
#   'literally',
#   'conversation',
#   'post',
#   'v',
#   'email',
#   'I',
#   'saw'],
#  ['key',
#   'word',
#   '``',
#   'annual',
#   '``',
#   'Have',
#   "n't",
#   'read',
#   'anyone',
#   'writing'],
#  ['A',
#   'productive',
#   'day',
#   'far',
#   'Happy',
#   'Days',
#   '...',
#   'head',
#   'spinning',
#   'things',
#   'voices',
#   'keep',
#   'calling',
#   '..',
#   'Lol',
#   '\U000fe334'],
#  ['Yeheyy', 'thank', 'much', 'Pinya', 'whoooah', 'win'],
#  ['Good',
#   'morning',
#   'dear',
#   'friends',
#   'lt',
#   'NUM',
#   'Listen',
#   '``',
#   'I',
#   'trance',
#   'lover',
#   '``',
#   'enjoy',
#   'D',
#   'Happy',
#   'Friday',
#   'lt',
#   'NUM'],
#  ['What', 'favorite', 'subject', 'school', '—', 'PHYSICS', 'T'],
#  ['congrats', 'good', 'news', 'heading', 'weekend'],
#  ['Take', 'head', 'I', 'stopped'],
#  ['ब', "n't", 'matter', 'Jungle', 'accommodate'],
#  ['hi', 'On', 'shouting', 'list', 'one', 'best', "'s", 'secret', 'behind'],
#  ['Swag', 'D'],
#  ['Wait', 'till', "'s", 'turn', 'go', 'mia'],
#  ['thanks'],
#  ['Having',
#   'lovely',
#   'time',
#   'going',
#   'flow',
#   'I',
#   'love',
#   'choosing',
#   'colours',
#   'Just',
#   '…'],
#  ['No', 'I', 'love', 'Finnigan', 'loyal', 'Royal'],
#  ['Fotoset', 'reusful', 'seems', 'like', 'somebody', 'fun', 'today', 'D'],
#  ['I', 'love'],
#  ['Quit', '``', 'You', 'selling', 'You', 'young', 'understand', 'muntu', '``'],
#  ['Another', 'gem', 'today', 'Falcos', 'cool'],
#  ['Good', 'morning', 'girl', 'Have', 'amazing', 'beach', 'D'],
#  ['You', 'welcome', 'D'],
#  ['Lol', "'s", 'tiring', 'good', 'looking'],
#  ['Wrong', 'Turn', 'NUM', 'amazing', 'movie'],
#  ['Glad',
#   'hear',
#   "'s",
#   'back',
#   'If',
#   'see',
#   'anything',
#   'else',
#   'crop',
#   'let',
#   'us',
#   'know',
#   '^BA'],
#  ['kill'],
#  ['pics', 'Nash', 'coming'],
#  ['I',
#   'make',
#   'sure',
#   'always',
#   'tissues',
#   'chocolate',
#   'tea',
#   'every',
#   'episode',
#   'It',
#   "n't",
#   'work',
#   'way'],
#  ['Contact',
#   'us',
#   'today',
#   "'ll",
#   'get',
#   'city',
#   'hotbed',
#   'bush',
#   'somewhere'],
#  ['Hi',
#   'Would',
#   'like',
#   'concert',
#   'Let',
#   'know',
#   'city',
#   'country',
#   'I',
#   "'ll",
#   'start',
#   'working',
#   'Thanks'],
#  ['Stats',
#   'day',
#   'arrived',
#   'NUM',
#   'new',
#   'follower',
#   'NO',
#   'unfollowers',
#   'via'],
#  ['glad', 'liked', 'Check', 'nice', 'stuff'],
#  ['follow', 'amp', 'follow', 'u', 'back'],
#  ['We',
#   'thrilled',
#   'first',
#   'international',
#   'assignment',
#   'aerial',
#   'camera',
#   'operators',
#   '....',
#   'Wales',
#   'come',
#   'Never',
#   'forget',
#   'smile'],
#  ['Friday',
#   'Night',
#   'Hong',
#   'Kong',
#   '...',
#   'On',
#   'Ferry',
#   '``',
#   'Central',
#   '``',
#   'meet',
#   'new',
#   'girlfriends',
#   'work',
#   'drink',
#   '.......'],
#  ['Family', 'time', 'D', 'Dj', 'Resto', '—'],
#  ['Good', 'morning', '—', 'drinkt', 'koffie'],
#  ['A6', 'If', 'I', 'Girl', 'My', 'Wardrobe', 'would', '``', 'W', '``'],
#  ['Is', 'Stargate', 'Atlantis', 'Such', 'cool', 'show'],
#  ['Great', 'Muaahhh'],
#  ['ohh',
#   'Hii',
#   'haha',
#   'thanks',
#   'info',
#   'I',
#   "'ll",
#   'check',
#   '🙈',
#   'maybe',
#   'di',
#   'nagsend',
#   'yung',
#   'order',
#   'form',
#   'ko',
#   'lt',
#   '/3',
#   'haha',
#   'thanks',
#   'ulit'],
#  ['happy', 'birthday', '🎉', '🎈'],
#  ['There', 'TRUST', 'without', 'us', 'UGLY', 'without', 'u'],
#  ['Leggete', 'qui', 'per', 'la', 'chat', 'Larry', '-Mar'],
#  ['Have', 'encouraged', 'employer', 'board', 'stuck', 'poster'],
#  ['Sticker', 'came', 'sponsor', 'prize', 'entry', 'The', 'tablet'],
#  ['goodnight',
#   'liam',
#   'I',
#   'hope',
#   'fantastic',
#   'day',
#   'today',
#   'sweet',
#   'dreams',
#   'baby',
#   'I',
#   'love',
#   'heart',
#   'D',
#   'xx'],
#  ['Oh',
#   'yeah',
#   'Milo',
#   'Aurini',
#   'Juicebro',
#   'fucking',
#   'pillars',
#   'respective',
#   'communities',
#   'D'],
#  ['Yeah',
#   'boii',
#   'Look',
#   'arrived',
#   'post',
#   'morning',
#   'The',
#   'latest',
#   "'s",
#   'new',
#   'bible',
#   'D'],
#  ['Ill', 'better', 'soon', '—', 'feeling', 'sick'],
#  ['LAMO',
#   'At',
#   'first',
#   'fangirl',
#   'hard',
#   '..',
#   "'d",
#   'love',
#   'share',
#   'platonic',
#   'pics',
#   'D',
#   'JUST',
#   'YOU',
#   'KNOW',
#   'FOR',
#   'SCIENCE'],
#  ['Morning',
#   '........',
#   "'s",
#   'FRIDAY',
#   'Happy',
#   'Friday',
#   'beautiful',
#   'people'],
#  ['Thank',
#   'We',
#   "'re",
#   'set',
#   'another',
#   'great',
#   'day',
#   'supporting',
#   'amp',
#   'helping'],
#  ['sounds', 'good', 'I', "'ll", 'see', 'Saturday', '✨'],
#  ['Live', 'night', 'two', 'fams'],
#  ["'re", 'welcome'],
#  ['The', 'picture', 'I', "'d", 'like', 'see', 'obituary', 'advert', '…'],
#  ['lovely', 'giveaway'],
#  ['dah', 'move'],
#  ['There',
#   "'s",
#   'nothing',
#   'cool',
#   'totally',
#   'someone',
#   'No',
#   'bitterness',
#   'anger',
#   'hatred',
#   'towards',
#   'Just',
#   'pure',
#   'indifference'],
#  ['u', 'wake', 'NUM', 'AM', 'suite', 'life', 'Zach', 'Cody'],
#  ['Oh',
#   "n't",
#   'know',
#   'But',
#   'yes',
#   'order',
#   'delivered',
#   'work',
#   'address',
#   "'s",
#   'added',
#   'address',
#   'book',
#   '^AC'],
#  ['Achieving',
#   'excellence',
#   'Music',
#   'Music',
#   'Producer',
#   'Mind',
#   'Boggling',
#   'amp',
#   'Fatiguing',
#   'Job',
#   '...',
#   'Baareeq',
#   '...'],
#  ['love', 'thanks', 'sharing'],
#  ['follow', 'amp', 'follow', 'u', 'back'],
#  ['hobby'],
#  ['yes', 'yes', 'yes', '...', 'I'],
#  ['Thank',
#   '``',
#   'Tweenie_Fox',
#   'Hi',
#   'please',
#   'click',
#   'list',
#   'hair',
#   'accessories',
#   'amp',
#   'products',
#   '``'],
#  ['Sometimes', "'re", 'tamang', 'hinala'],
#  ['I', "'m", 'following'],
#  ['hello',
#   'babe',
#   'got',
#   'Niam',
#   'access',
#   'Could',
#   'I',
#   'give',
#   'something',
#   'ship',
#   'dm'],
#  ['Selfieeeee'],
#  ['Especially', 'three', 'LASS', 'w/', 'Aling'],
#  ['Hi',
#   'nice',
#   'swim',
#   'sis',
#   'Can',
#   'I',
#   'get',
#   'shout',
#   'please',
#   'would',
#   'make',
#   'day',
#   'xx'],
#  ['haha',
#   'hope',
#   'I',
#   "n't",
#   'got',
#   'work',
#   'tho',
#   '..',
#   'Bout',
#   'quit',
#   'I',
#   'p'],
#  ['goodbye',
#   "n't",
#   'forget',
#   'feminists',
#   'fought',
#   'right',
#   'act',
#   'like',
#   'snobby',
#   'little',
#   'bitch',
#   'goodnight'],
#  ['follow', 'amp', 'follow', 'u', 'back'],
#  ['CAROLINE',
#   'Caroline',
#   'guys',
#   'say',
#   "'s",
#   'mighty',
#   'fine',
#   '🔥',
#   'I',
#   'threw',
#   'little',
#   'making',
#   'HBD',
#   '❤',
#   '️'],
#  ['follback'],
#  ['Time', 'jogging', 'p'],
#  ['place', 'I', 'hope', 'I', '’', 'pro', 'remote', 'work', 'AND', 'traveling'],
#  ['Newly', 'listed', 'EBay', 'store', '...'],
#  ['The',
#   'new',
#   'characters',
#   'look',
#   'amazing',
#   'preorder',
#   'starter',
#   'pack',
#   'store',
#   'today',
#   'D'],
#  ['I', "'m", 'want', 'talk'],
#  ['I', 'always', 'tweet', 'hit', 'snap', '...', 'one', 'ever', 'worth', 'try'],
#  ['The', 'homies', 'bought', 'skins', 'bday', 'D'],
#  ['Just', 'chant', 'Jai', 'Italy', 'NUM', 'times', 'fast'],
#  ['Heeeeyyy', 'Can', 'follow', 'fan', 'account', 'Thank'],
#  ['UK'],
#  ['thank', 'D'],
#  ['woah', 'nice', 'nice'],
#  ['u', 'welcome', '♥'],
#  ['good'],
#  ['And',
#   "'s",
#   "'s",
#   '★',
#   '★',
#   '★',
#   '★',
#   'review',
#   'Phew',
#   'We',
#   "'re",
#   'literally',
#   'overwhelmed'],
#  ['Hi',
#   'Would',
#   'like',
#   'concert',
#   'Let',
#   'know',
#   'city',
#   'country',
#   'I',
#   "'ll",
#   'start',
#   'working',
#   'Thanks'],
#  ['amp',
#   'baby',
#   '😊',
#   '😊',
#   '😊',
#   'next',
#   'time',
#   "'s",
#   'house',
#   'I',
#   'whenever'],
#  ['got', 'thanks', 'g'],
#  ['Have', 'encouraged', 'employer', 'board', 'stuck', 'poster'],
#  ['Hugs', 'ang', 'Kisses', 'philippines'],
#  ['I', "'ve", 'entered', 'WIN', 'huge', 'package', 'amp', 'ENTER', 'HERE'],
#  ['yes', 'works'],
#  ['follow', 'amp', 'follow', 'u', 'back'],
#  ['Hi',
#   'great',
#   'connect',
#   'We',
#   'specialise',
#   'thermal',
#   'imaging',
#   'surveys',
#   '–',
#   'need',
#   'us'],
#  ['yeah', 'bruise', 'rib'],
#  ['😀',
#   '😁',
#   '😂',
#   '😃',
#   '😄',
#   '😅',
#   '😉',
#   'No',
#   'No',
#   'wo',
#   "n't",
#   'give',
#   'dear',
#   "n't",
#   'worry'],
#  ['thought', 'might', 'like', 'D'],
#  ['Oh', 'Me', 'Oh', 'Me', 'Oh', 'rela', 'building'],
#  ['Low', 'priority', 'match', 'hahaha'],
#  ['fback'],
#  ['I',
#   'want',
#   'Harry',
#   'Dm',
#   'bc',
#   'I',
#   'wan',
#   'na',
#   'give',
#   'surprise',
#   'friend',
#   'birthday',
#   'I',
#   'wan',
#   'na',
#   'make',
#   'happy'],
#  ['Is',
#   'opportune',
#   'time',
#   'NUM',
#   'collapse',
#   'chaotic',
#   'Cosas',
#   'lt',
#   '--',
#   'note',
#   'alliteration'],
#  ['going', 'well', 'oppayaa', 'How', "'s", 'D'],
#  ['best', 'want', 'body'],
#  ['new',
#   'show',
#   'U',
#   'ca',
#   "n't",
#   'lick',
#   'ur',
#   'elbow',
#   '.seems',
#   'interesting',
#   '....'],
#  ['Stats',
#   'day',
#   'arrived',
#   'NUM',
#   'new',
#   'followers',
#   'NO',
#   'unfollowers',
#   'via'],
#  ['“', 'Emu', 'stoked', 'thank', 'G', '”'],
#  ['Woke', 'yo', 'fav', 'tweet', 'made', 'day', '😂', '😂', 'G'],
#  ['Remember',
#   "n't",
#   'need',
#   'people',
#   "'s",
#   'approval',
#   'God',
#   "'s",
#   'approval'],
#  ['jisung', 'kid', 'sunshine'],
#  ['mm', 'okay', 'thanks'],
#  ['Message',
#   'us',
#   'right',
#   'Nicola',
#   'forward',
#   'Brighten',
#   'day',
#   'D',
#   'Helen'],
#  ['follow', 'amp', 'follow', 'u', 'back'],
#  ['CONGRATS'],
#  ['Hi',
#   'Brian',
#   'I',
#   "'ll",
#   'get',
#   'shipped',
#   'today',
#   'take',
#   'NUM',
#   'NUM',
#   'weeks',
#   'Australia',
#   'Many',
#   'thanks'],
#  ['good', 'fun', 'time', 'ol', 'bones', 'creaking'],
#  ['Eh', 'abUtI', 'WelcOmE', 'TweetLand', '.....', 'Lol', 'p'],
#  ['thx', 'And', 'Android', 'support', 'Xmas'],
#  ['A', 'great', 'Skyblock', 'stream'],
#  ['standing', 'always', 'Belieber', 'bcause', 'NUM', 'Die'],
#  ['I', 'streaming', 'Twitch', 'Join', 'D', 'lockedbeast1'],
#  ['..', 'sympathy', 'laugh'],
#  ['would', 'like', 'xo'],
#  ['Awesome', 'D'],
#  ['unnieeee'],
#  ['Tonight', 'Night', '...'],
#  ['well', "'re", 'wild', 'ride', 'gt', 'D'],
#  ['Hahaha',
#   'tell',
#   'anytime',
#   'wan',
#   'na',
#   'taste',
#   'oh',
#   'yer',
#   'address',
#   'send'],
#  ['thanks', 'team', 'yellow'],
#  ['Maganda', 'You', 'look', 'pretty', 'short', 'hair', 'cute', 'D'],
#  ['Good', 'morning', 'gorgeous', 'Mistress', 'Saphire'],
#  ['I', "'m", 'work', 'I', "'m", 'busy', 'I', 'help', 'I', 'finish', 'home'],
#  ['Thanks',
#   'amazing',
#   'NUM',
#   'Followers',
#   'Instagram',
#   'If',
#   'you´re',
#   'among',
#   'yet',
#   'feel',
#   'free',
#   'connect',
#   '...'],
#  ['Coconut', 'Sambal', 'Mussels', 'Recipe'],
#  ['Thanks', 'Kalin'],
#  ['Follow', 'Mixcloud'],
#  ['fback'],
#  ['Thankyou', 'Greetings', 'Australia'],
#  ['I',
#   'ca',
#   'nt',
#   'work',
#   'sarcasm',
#   'know',
#   'Chelsea',
#   'supports',
#   'think',
#   'useless',
#   'comes',
#   'ok'],
#  ['follow', 'back'],
#  ['I',
#   'come',
#   'back',
#   'next',
#   'Thursday',
#   'We',
#   'still',
#   'hang',
#   'hehe',
#   'said',
#   'hi',
#   'love',
#   'u'],
#  ['Benson',
#   'gorgeous',
#   'Thank',
#   'much',
#   'sharing',
#   'us',
#   'You',
#   'also',
#   'enter',
#   'Facebook',
#   '...'],
#  ['look', 'solid', '16/17'],
#  ['Great', 'night', 'D'],
#  ['NUM', '°', 'C', '😜', 'change', 'days', 'good'],
#  ['Add', 'Snapchat', 'MaryHicks18'],
#  ['``',
#   'fleekile',
#   'mbalula',
#   '``',
#   'said',
#   'repeat',
#   'love',
#   'south',
#   'africa'],
#  ['friend',
#   'making',
#   'fun',
#   'fact',
#   'mexican',
#   'hurt',
#   'feelings',
#   "'ll",
#   'leave',
#   'scarred',
#   'life'],
#  ["'s", 'office', 'today'],
#  ['like', 'amazing', 'donut', 'recipe', 'share', 'lovers'],
#  ['Despite', 'weather', 'today', 'wedding', 'going', 'beautiful'],
#  ['Where', 'Was', 'Tony', 'Stark', 'From', 'Incredible', 'Tony', 'Pictures'],
#  ['To', 'sit', 'write', 'poems', 'stories', "'s", 'bubbling', 'head~'],
#  ['Last', 'night'],
#  ['Dale', 'send', 'billion', 'kiss', 'Have', 'magical', 'day'],
#  ['That', 'might', 'work', 'Have', 'great', 'weekend', '\\OP'],
#  ['Smile', "'s"],
#  ['cast', 'vote', 'next', 'elections'],
#  ['Have', 'done', 'Thank', 'tweet'],
#  ['Oh', 'piggin', 'go', 'yer', 'give', 'us', 'peace'],
#  ['Appreciate', 'follow', 'heard', 'botanical', 'soaps'],
#  ['love', 'u', 'NUM'],
#  ['Late', 'upload', 'Freshly', 'done/3weeks', 'old', 'healed'],
#  ['oh',
#   'I',
#   'bed',
#   'haha',
#   'I',
#   'ca',
#   "n't",
#   'sleep',
#   'though',
#   'My',
#   'day',
#   'exciting'],
#  ['thx', 'Tobi', 'bro', 'D'],
#  ['How', 'good', 'I', 'think', 'first', 'ISP'],
#  ["'ll", 'steel', 'next', 'Wednesday', 'see', "'s", 'like'],
#  ['hey'],
#  ['definitely',
#   'loves',
#   'making',
#   'people',
#   'smile',
#   'cause',
#   'I',
#   'swear',
#   'since',
#   'I',
#   'met',
#   'earlier',
#   'I',
#   "n't",
#   'stopped',
#   'smiling',
#   'love',
#   'cam',
#   '😭',
#   '❤',
#   '️'],
#  ['...', 'except', 'Lord', "masha'Allah"],
#  ['French',
#   'fans',
#   'made',
#   'movie',
#   'WWAT',
#   'France',
#   'last',
#   'year',
#   'videos',
#   'photos'],
#  ['It', 'fixed', 'thanks', 'feedback'],
#  ['Thanks',
#   'everyone',
#   'came',
#   'stream',
#   'D',
#   'Hope',
#   'guys',
#   'enjoyed',
#   'Night'],
#  ['YAAAAAAAAY', 'thx'],
#  ['Looking', 'forward', 'reviewing'],
#  ['Thank', 'Beiruting'],
#  ['fback'],
#  ['Thanks', 'updating', 'profile', 'page'],
#  ['Lovely', 'coffee'],
#  ['Here', "'s", 'cute', 'panda', 'make', 'day'],
#  ['thank', 'eonnie'],
#  ['Hi',
#   'Saw',
#   'u',
#   'follow',
#   'thought',
#   'u',
#   'might',
#   'like',
#   '``',
#   'Dark',
#   '``',
#   '.Plz',
#   'let',
#   'us',
#   'know',
#   'u',
#   'think'],
#  ['favourite', 'Cream', 'Soda'],
#  ['I',
#   'love',
#   'body',
#   "'s",
#   'fuller',
#   'shit',
#   'even',
#   "'s",
#   'lol',
#   'I',
#   "'m",
#   'happy',
#   'healthy',
#   'happy',
#   'happy',
#   '..',
#   '💓'],
#  ['Rettweet'],
#  ['real',
#   'MVG',
#   'MOST',
#   'VALUABLE',
#   'GIRLFRIEND',
#   'staying',
#   'till',
#   'Madrid',
#   'game',
#   'starts'],
#  ['sore', 'ya'],
#  ['I', "'m", 'excited', 'definitely', 'meet'],
#  ['coming',
#   'Bergerac',
#   'Have',
#   'first',
#   'team',
#   'left',
#   'u21',
#   "'s",
#   'I',
#   "'d",
#   'know',
#   'chants'],
#  ['choice', 'food', 'Left', 'individuals'],
#  ['The',
#   'episode',
#   'excellent',
#   'far',
#   'I',
#   'love',
#   'Adam',
#   'Beach',
#   "'s",
#   'movies',
#   'amp',
#   'shows',
#   'I',
#   "'m",
#   'looking',
#   'forward',
#   'seeing',
#   'Suicide',
#   'Squad',
#   'next',
#   'year'],
#  ['Growing',
#   'fond',
#   'Christopher',
#   "n't",
#   'like',
#   'initially',
#   'cocky',
#   "n't",
#   'really',
#   'prove',
#   'attitude',
#   "'s",
#   'improving',
#   'D'],
#  ['sounds',
#   'good',
#   'Can',
#   'DM',
#   'email',
#   'address',
#   'Will',
#   'suggest',
#   'dates',
#   'coffee'],
#  ['It', 'indeed', 'many', 'thanks'],
#  ['Just', 'smile', 'even', 'Pain'],
#  ['Hi', 'happys'],
#  ['Funny', 'Intelligent', 'strong', 'funny', 'Just', 'funny', '...'],
#  ['Hello', 'Get', 'Youth', 'Job', 'Opportunities', 'follow', 'gt', 'gt'],
#  ['using', 'Cs'],
#  ['ever', 'watch', 'certain', 'people', "'s", 'snapchat', 'bc', 'know'],
#  ["'s", 'ok', 'I', 'know', 'busy'],
#  ['Last', 'NUM', 'exams'],
#  ['forgot', 'u'],
#  ['Fun', 'fact', 'I', 'love', 'meeting', 'new', 'people'],
#  ['I',
#   'know',
#   'home',
#   'based',
#   'office',
#   'busy',
#   'feeling',
#   'Pity',
#   'knee',
#   'happened'],
#  ['SALE', 'FLEUR', 'DRESS', 'CREAM', 'IDR', '325.000', 'gt', 'IDR', '200.000'],
#  ['Thankyou'],
#  ['follow', 'amp', 'follow', 'u', 'back'],
#  ['Is',
#   'Tompolo',
#   'meeting',
#   'aimed',
#   'stopping',
#   'sale',
#   'oil',
#   'find',
#   'buyers',
#   'D'],
#  ["'s", 'true', "n't", 'disappoint', 'Looking', 'forward', 'Paper', 'Towns'],
#  ['That', "'s", 'I', 'need', 'know', 'everything', 'going', 'okay'],
#  ['I', 'say', 'less', 'slacking', 'amp', 'getting', 'cracking'],
#  ['I', "n't", 'know', 'name', 'particularly', 'striking', 'Happy', 'days'],
#  ['Hey', "'s", 'invite', 'join', 'Scope', 'influencer'],
#  ['NUM', 'My', 'Bad', 'Mam', 'p'],
#  ['Lovely', 'looking', 'cake', 'bet', 'tastes', 'good'],
#  ['FeyTyaz', 'Follback', 'ya'],
#  ['I',
#   'found',
#   'last',
#   'night',
#   'lets',
#   'say',
#   'instant',
#   'stiffening',
#   'interest'],
#  ['Rettweet'],
#  ['fback'],
#  ['Rettweet'],
#  ['ricky_febs', 'Follback', 'ya'],
#  ['Got',
#   'Secrets',
#   'Grindea',
#   'Courier',
#   'Crypts',
#   'possibly',
#   'Arma',
#   'NUM',
#   'record',
#   'today',
#   '.....',
#   'Gosh',
#   'And',
#   'new',
#   'game',
#   'looks',
#   'like',
#   'Limbo'],
#  ['follow', 'amp', 'follow', 'u', 'back'],
#  ['thanks', 'retweeting', 'orchard', 'art', 'show', 'super', 'weekend'],
#  ['Karachi',
#   'ka',
#   'Venice',
#   'rains',
#   '“',
#   'Several',
#   'parts',
#   'Karachi',
#   'witness',
#   'accumulated',
#   'rain',
#   'water',
#   'Wionr1evBo',
#   '”'],
#  ['maroon', 'cocktail', 'dresses'],
#  ['fback', 'po'],
#  ['NUM', 'NUM', 'real', 'quick'],
#  ['Morning',
#   'Mine',
#   '1100D',
#   'Usually',
#   'auto',
#   'focus',
#   'I',
#   'use',
#   'manual',
#   'really',
#   'close',
#   'like',
#   'shooting',
#   'veins',
#   'crackle',
#   'glaze'],
#  ['new', 'layout', 'looks', 'bomb', '-g'],
#  ['Thanks',
#   'connecting',
#   'Hope',
#   "'re",
#   'Great',
#   'Day',
#   'Have',
#   'social',
#   'website',
#   'question',
#   'Just',
#   'ask'],
#  ['pake'],
#  ['hi', 'made', 'changes', 'design', 'hope', 'like'],
#  ['joim', 'I', 'feed', 'troops', 'via'],
#  ['Any', 'brands', 'wanting', 'review', 'BEAUTY', 'products', 'blog', 'mail'],
#  ['The_MadStork', 'Follback', 'ya'],
#  ['Good', 'luck', 'Shaun'],
#  ['yes'],
#  ['Anyone', 'wants', 'added', 'bot', 'DM'],
#  ['Chloe',
#   'I',
#   'watched',
#   '``',
#   'Let',
#   '``',
#   'yesterday',
#   'really',
#   'awesome',
#   'Really',
#   'talented',
#   'intelligent',
#   'actress',
#   'beautiful'],
#  ['could', 'get', 'free', 'solo', 'dms', 'Any', 'give', 'away', 'xoxo'],
#  ['thanks', 'sharing', 'Wishing', 'wicked', 'weekend'],
#  ['Hola',
#   'juan',
#   '..',
#   'sending',
#   'big',
#   'Hi',
#   'Houston',
#   'tx',
#   'I',
#   "'ve",
#   'fan',
#   'jenni',
#   'family',
#   'year',
#   "'s",
#   'I',
#   'stumble',
#   'upon',
#   'video'],
#  ['No', 'choker', 'btw'],
#  ['seouljins', 'fine', 'tbh'],
#  ['Photoset',
#   'sadomasochistsparadise',
#   'Wynter',
#   'bottoms-',
#   'outtake',
#   'Sadomasochist',
#   '’',
#   'Paradise',
#   'Cuties'],
#  ['You', 'make', 'day', 'smiling'],
#  ['fback'],
#  ['D', 'ty', 'bby'],
#  ['Please', 'enjoy', 'clip', 'losing', 'shit', 'cypher'],
#  ['next', 'week', 'office', 'lets', 'go'],
#  ['thank', 'following', 'D'],
#  ['Stats',
#   'day',
#   'arrived',
#   'NUM',
#   'new',
#   'followers',
#   'NO',
#   'unfollowers',
#   'via'],
#  ['Amen', 'Thanks'],
#  ['Hi',
#   'BAM',
#   'Can',
#   'follow',
#   'bestfriend',
#   'She',
#   'loves',
#   'lot',
#   'See',
#   'Warsaw',
#   'lt',
#   'NUM',
#   'Love',
#   'lt',
#   'NUM',
#   'x32'],
#  ['follow', 'amp', 'follow', 'u', 'back'],
#  ['paper', 'girl', 'D'],
#  ['I', 'know', 'would', 'lovely', 'pic', 'x'],
#  ['Planted', 'people', 'allowed', 'thing', 'every', 'thing', 'p'],
#  ['``',
#   'This',
#   'Corner',
#   '``',
#   'fucking',
#   'Dope',
#   'Getting',
#   'addicted',
#   '..',
#   'Great',
#   'Job',
#   'D'],
#  ['My', 'bby', 'gurl'],
#  ['Hey', 'hey', 'D'],
#  ['still',
#   'suck',
#   'editing',
#   'turns',
#   'something',
#   'special',
#   'I',
#   'owe',
#   'guys'],
#  ['Visit', 'blog', 'thanks', 'D'],
#  ['YOU', "'RE", 'UGLY', 'DANIEL', 'good', 'ape'],
#  ['Happy', 'bday', 'Saar', '....', 'Have', 'great', 'year', 'ahead', '...'],
#  ['Thought',
#   'might',
#   'I',
#   'saw',
#   'I',
#   'loved',
#   'verse',
#   'The',
#   'butterfly',
#   'part',
#   'bonus'],
#  ['Thank', 'OK', 'Have', 'fun', 'Enjoy', 'day', 'u'],
#  ['well', 'good', 'morning', 'D'],
#  ['would', 'follow'],
#  ['Busy',
#   'productive',
#   'day',
#   'filled',
#   'tears',
#   'hours',
#   'hours',
#   'laughter',
#   'Today',
#   'good',
#   'day'],
#  ['hi', 'You', '5sos', 'tickets', 'Dm'],
#  ['Yummmyyy', '....', '—', 'eating', 'dosa'],
#  ['I', 'D'],
#  ['probably',
#   'easier',
#   'meet',
#   'station',
#   'Unless',
#   'particularly',
#   'want',
#   'show',
#   'house'],
#  ['A', 'Huge', 'amp', 'Warm', 'Welcome'],
#  ['ACHI',
#   'I',
#   'busy',
#   'next',
#   'week',
#   'exams',
#   'Hope',
#   'understand',
#   'I',
#   'ca',
#   'nt',
#   'tweet',
#   'youuu',
#   'Bawi',
#   'ako',
#   'queenesther'],
#  ['Looking', 'sharp'],
#  ['yess', 'NUM', 'year', 'younger', 'u', 'wonder', 'huge', 'boy'],
#  ['I', "'m", 'playing', 'Brain', 'Dots'],
#  ['Ha', 'All', 'one', 'picture'],
#  ['ready'],
#  ['Thanks', 'share'],
#  ['fback'],
#  ['follow', 'amp', 'follow', 'u', 'back'],
#  ['Happy', 'birthday', 'buddy', 'D'],
#  ['Thank'],
#  ['sigh', '``', 'Bruhhh', '“', 'Call', 'daddy', 'one', 'time', '”', '``'],
#  ...]

# %% [markdown]
# ### TFIDF Calculations

# %%
def get_tf(term, document):

    delimiter = " "
    term_normalized = delimiter.join(utils.canonize(term))

    # print(term_normalized)

    numOfAppearancesInDoc = document.count(term_normalized)
    totalNumOfTermsInDoc = len(document)

    # print("NumOfAppearancesInDoc: {}".format(numOfAppearancesInDoc))
    # print("TotalNumOfTermsInDoc: {}".format(totalNumOfTermsInDoc))
  
    if (totalNumOfTermsInDoc != 0):
        return numOfAppearancesInDoc / totalNumOfTermsInDoc
    else:
        return 0

get_tf("demo string", "This is a 'demo string' in a demo sentence")
# Out:
# 0.023809523809523808

# %%
def get_idf(term, corpus):

    delimiter = " "
    term_normalized = delimiter.join(utils.canonize(term))

    numOfDocsInCorpus = len(corpus)
    numOfAppearrancesInCorpus = 0
    
    for document in corpus:
        
        if term_normalized in document:
            
            numOfAppearrancesInCorpus += 1

    # print(numOfAppearrancesInCorpus)

    if (numOfAppearrancesInCorpus != 0):
        return numOfDocsInCorpus / numOfAppearrancesInCorpus
    else:
        # Return high IDF value as the term is very uncommon
        return 10000


get_idf("Scotland", normalized_tweets)
# Out:
# 2500.0

# %%
def get_tfidf(term, document, corpus):

    # print(get_tf(term, document))
    # print(get_idf(term, corpus))

    return get_tf(term, document) * get_idf(term, corpus)

# %%
def get_keywords(sentence, corpus, numOfKeywords = 10):

    

    # Get the most frequent named entities (Using the raw string here for better entity recognition)
    doc = nlp(sentence)
    named_entities = GetNamedEntities(doc)

    entityCounts = {}

    for entity in named_entities:
        if entity not in entityCounts:
            entityCounts[entity] = sentence.count(entity)




    # Get the most popular terms that are not entities
    normalized_sentence = utils.canonize(RemoveNamedEntities(sentence, named_entities))
    
    mostRelevantWords = {}


    for term in normalized_sentence:
        if term not in mostRelevantWords:

            pos_tag = nltk.pos_tag(word_tokenize(term))[0][1]

            mostRelevantWords[term] = [get_tfidf(term, normalized_sentence, corpus), pos_tag]
    
    return dict(sorted(mostRelevantWords.items(), key=lambda item: item[1], reverse=True)[:5]), dict(sorted(entityCounts.items(), key=lambda item: item[1], reverse=True)[:5])

# %%
pos_tag(word_tokenize("John"))
# Out:
# [('John', 'NNP')]

# %%
sentence = "Tried a new recipe for dinner and let's just say... ordering takeout would have been a better idea 🍽️😅 #KitchenDisasters"

get_keywords(sentence, normalized_tweets)
# Out:
# ({'ordering': [714.2857142857142, 'VBG'],
#   'takeout': [714.2857142857142, 'NN'],
#   '🍽️😅': [714.2857142857142, 'NN'],
#   'recipe': [238.0952380952381, 'NN'],
#   'Tried': [142.85714285714286, 'VBN']},
#  {'KitchenDisasters': 1})

# %% [markdown]
# ## Test Sentence Generation

# %%
from nltk.parse.generate import generate, demo_grammar
from nltk import CFG

spec = """
    S -> NP VP
    NP -> DT NN | DT JJ NN | PRP | NP PP
    VP -> VBD NP | VB NP | VBD ADVP | VB ADVP | VP PP | VP CONJ VP
    PP -> IN NP
    ADVP -> RB | ADVP RB
    DT -> 'the' | 'a' | 'an' | 'this' | 'that' | 'these' | 'those' | 'my' | 'your'
    NN -> 'cat' | 'dog' | 'man' | 'woman' | 'park' | 'book'
    JJ -> 'big' | 'small' | 'green' | 'red' | 'beautiful' | 'old' | 'young'
    RB -> 'quickly' | 'happily' | 'very'
    PRP -> 'I' | 'you' | 'he' | 'she' | 'it' | 'we' | 'they'
    VBD -> 'chased' | 'saw' | 'read' | 'walked'
    VB -> 'chase' | 'see' | 'read' | 'walk'
    IN -> 'in' | 'on' | 'at' | 'by' | 'with'
    CONJ -> 'and' | 'or' | 'but'
    VBG -> 'ordering'
    NN -> 'takeout' | '🍽️😅' | 'recipe'
    VBN -> 'Tried'
    """

grammar = CFG.fromstring(spec)
print(grammar)

demo_grammar
# Out:
# Grammar with 67 productions (start state = S)
#     S -> NP VP
#     NP -> DT NN
#     NP -> DT JJ NN
#     NP -> PRP
#     NP -> NP PP
#     VP -> VBD NP
#     VP -> VB NP
#     VP -> VBD ADVP
#     VP -> VB ADVP
#     VP -> VP PP
#     VP -> VP CONJ VP
#     PP -> IN NP
#     ADVP -> RB
#     ADVP -> ADVP RB
#     DT -> 'the'
#     DT -> 'a'
#     DT -> 'an'
#     DT -> 'this'
#     DT -> 'that'
#     DT -> 'these'
#     DT -> 'those'
#     DT -> 'my'
#     DT -> 'your'
#     NN -> 'cat'
#     NN -> 'dog'
#     NN -> 'man'
#     NN -> 'woman'
#     NN -> 'park'
#     NN -> 'book'
#     JJ -> 'big'
#     JJ -> 'small'
#     JJ -> 'green'
#     JJ -> 'red'
#     JJ -> 'beautiful'
#     JJ -> 'old'
#     JJ -> 'young'
#     RB -> 'quickly'
#     RB -> 'happily'
#     RB -> 'very'
#     PRP -> 'I'
#     PRP -> 'you'
#     PRP -> 'he'
#     PRP -> 'she'
#     PRP -> 'it'
#     PRP -> 'we'
#     PRP -> 'they'
#     VBD -> 'chased'
#     VBD -> 'saw'
#     VBD -> 'read'
#     VBD -> 'walked'
#     VB -> 'chase'
#     VB -> 'see'
#     VB -> 'read'
#     VB -> 'walk'
#     IN -> 'in'
#     IN -> 'on'
#     IN -> 'at'
#     IN -> 'by'
#     IN -> 'with'
#     CONJ -> 'and'
#     CONJ -> 'or'
#     CONJ -> 'but'
#     VBG -> 'ordering'
#     NN -> 'takeout'
#     NN -> '🍽️😅'
#     NN -> 'recipe'
#     VBN -> 'Tried'
# "\n  S -> NP VP\n  NP -> Det N\n  PP -> P NP\n  VP -> 'slept' | 'saw' NP | 'walked' PP\n  Det -> 'the' | 'a'\n  N -> 'man' | 'park' | 'dog'\n  P -> 'in' | 'with'\n"

# %%
for sentence in generate(grammar, n=10):
    print(' '.join(sentence))
# Out:
# the cat chased the cat
# the cat chased the dog
# the cat chased the man
# the cat chased the woman
# the cat chased the park
# the cat chased the book
# the cat chased the takeout
# the cat chased the 🍽️😅
# the cat chased the recipe
# the cat chased a cat
